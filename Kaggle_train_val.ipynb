# %%
# !pip install scikeras==0.13.0 scikit-learn==1.4.2
# Out:
# Collecting scikeras==0.13.0
#   Downloading scikeras-0.13.0-py3-none-any.whl.metadata (3.1 kB)
# Collecting scikit-learn==1.4.2
#   Downloading scikit_learn-1.4.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.12/dist-packages (from scikeras==0.13.0) (3.13.2)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.12/dist-packages (from scikit-learn==1.4.2) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn==1.4.2) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn==1.4.2) (1.5.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn==1.4.2) (3.6.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras==0.13.0) (1.4.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras==0.13.0) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras==0.13.0) (0.1.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras==0.13.0) (3.16.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras==0.13.0) (0.19.1)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras==0.13.0) (0.5.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras==0.13.0) (26.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from optree->keras>=3.2.0->scikeras==0.13.0) (4.15.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.2.0->scikeras==0.13.0) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.2.0->scikeras==0.13.0) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->scikeras==0.13.0) (0.1.2)
# Downloading scikeras-0.13.0-py3-none-any.whl (26 kB)
# Downloading scikit_learn-1.4.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 25.9 MB/s eta 0:00:00
# Installing collected packages: scikit-learn, scikeras
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.6.1
#     Uninstalling scikit-learn-1.6.1:
#       Successfully uninstalled scikit-learn-1.6.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# umap-learn 0.5.12 requires scikit-learn>=1.6, but you have scikit-learn 1.4.2 which is incompatible.
# hdbscan 0.8.43 requires scikit-learn>=1.6, but you have scikit-learn 1.4.2 which is incompatible.
# Successfully installed scikeras-0.13.0 scikit-learn-1.4.2

# %%
#Librerías
import pickle
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from matplotlib.gridspec import GridSpec

from sklearn.base import clone
from sklearn.model_selection import (
    StratifiedKFold,
    cross_validate,
    RandomizedSearchCV
)

from sklearn.metrics import (
    classification_report,
    make_scorer,
    accuracy_score,
    f1_score,
    roc_auc_score,
    recall_score,
    balanced_accuracy_score,
    average_precision_score,
    roc_curve,
    auc,
    confusion_matrix,
    ConfusionMatrixDisplay
)

from scikeras.wrappers import KerasClassifier

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.optimizers import Adam


# Montamos Google Drive en Colab
from google.colab import drive
drive.mount('/content/drive')

# Ruta base de trabajo
RUTA_BASE = "/content/drive/MyDrive/"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Cargamos las particiones de entenamiento y test previamente preprocesadas y balanceadas mediante distintas estrategias.

# %%
# Carga datasets preprocesados y balanceados
x_train_desbal = pd.read_csv(RUTA_BASE + "x_train_desbal.csv")
x_train_UNDER  = pd.read_csv(RUTA_BASE + "x_train_UNDER.csv")
x_train_SMOTE  = pd.read_csv(RUTA_BASE + "x_train_SMOTE.csv")
x_test_final   = pd.read_csv(RUTA_BASE + "x_test_final.csv")

# Convertimos las etiquetas categóricas ("Sí"/"No") a codificación binaria
# para entrenamiento supervisado.
def load_y(path):
    return (
        pd.read_csv(path)
        .squeeze()
        .map({"No": 0, "Sí": 1})
        .astype(int)
    )

y_train_desbal = load_y(RUTA_BASE + "y_train_desbal.csv")
y_train_UNDER  = load_y(RUTA_BASE + "y_train_UNDER.csv")
y_train_SMOTE  = load_y(RUTA_BASE + "y_train_SMOTE.csv")
y_test_final   = load_y(RUTA_BASE + "y_test_final.csv")


# Calculamos el peso relativo de la clase minoritaria
scale = (y_train_desbal == 0).sum() / (y_train_desbal == 1).sum()
print(f"scale_pos_weight: {scale:.2f}")

# Copias explícitas para el entrenamiento de NN
x_under_df  = x_train_UNDER.copy()
x_desbal_df = x_train_desbal.copy()
x_smote_df  = x_train_SMOTE.copy()
x_test_df   = x_test_final.copy()

input_dim = x_under_df.shape[1]

# NN — codificación 0/1
y_train_under_nn  = pd.Series((y_train_UNDER  == 1).astype(int).values, name="stroke")
y_train_desbal_nn = pd.Series((y_train_desbal == 1).astype(int).values, name="stroke")
y_train_smote_nn  = pd.Series((y_train_SMOTE  == 1).astype(int).values, name="stroke")
y_test_nn         = pd.Series((y_test_final   == 1).astype(int).values, name="stroke")
# Out:
# scale_pos_weight: 19.54

# %% [markdown]
# Definición global de CV y métricas

# %%
# Validación cruzada estratificada:
# mantiene la proporción de clases en cada fold
cv = StratifiedKFold(
    n_splits=5,
    shuffle=True,
    random_state=24
)

# Métricas utilizadas durante validación cruzada
scoring = {
    "Recall": make_scorer(recall_score, pos_label=1),
    "F1": make_scorer(f1_score, pos_label=1),
    "AUROC": "roc_auc",
    "Accuracy": "accuracy",
    "BalancedAccuracy": "balanced_accuracy"
}

metricas = [
    "mean_test_Accuracy",
    "mean_test_F1",
    "mean_test_AUROC",
    "mean_test_Recall",
    "mean_test_BalancedAccuracy"
]

# %% [markdown]
# # Entrenamiento de modelos

# %% [markdown]
# Creamos una función general para el entrenamiento y evaluación de modelos mediante RandomizedSearchCV

# %%
# Función para entrenamiento por RandomizedSearchCV
def ejecutar_random_search(
    modelo,
    parametros,
    x_train,
    y_train,
    nombre_modelo,
    cv,
    scoring,
    metricas,
    n_iter=10,
    refit="AUROC",
    random_state=24,
    fit_params=None
):

    print("=" * 70)
    print(f"Entrenamiento: {nombre_modelo}")
    print("=" * 70)

    #Deteccion de red neuronal para variar n_jobs
    es_red_neuronal = (
    "keras" in str(type(modelo)).lower()   # detección por nombre de clase
    or isinstance(modelo, tf.keras.Model)  # detección directa de TF/Keras
    )

    # Asignación automática de n_jobs según tipo de modelo
    n_jobs = 1 if es_red_neuronal else -1

    # Configuración de RandomizedSearchCV
    random_search = RandomizedSearchCV(
        estimator=modelo,
        param_distributions=parametros,
        n_iter=n_iter,
        cv=cv,
        scoring=scoring,
        refit=refit,
        n_jobs=n_jobs,
        verbose=2,
        random_state=random_state
    )

    # Entrenamiento
    if fit_params is None:
        random_search.fit(x_train, y_train)
    else:
        random_search.fit(x_train, y_train, **fit_params)

    # Mejor modelo
    best_model = random_search.best_estimator_

    # Índice y resultados CV
    best_index = random_search.best_index_
    cv_results = random_search.cv_results_

    # Métricas medias del mejor modelo
    print("\nMétricas medias en validación cruzada:")

    for m in metricas:
        print(f"{m}: {cv_results[m][best_index]:.4f}")

    # Hiperparámetros del mejor modelo
    print("\nMejores hiperparámetros:")

    for clave, valor in random_search.best_params_.items():
        print(f"{clave}: {valor}")

    print("\n")

    # Return de la función
    return {
        "search": random_search,
        "best_model": best_model,
        "best_params": random_search.best_params_,
        "cv_results": cv_results,
        "best_index": best_index
    }

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# Definimos el modelo base
rf = RandomForestClassifier(random_state=24)

# %% [markdown]
# ### SMOTE

# %%
# Rejilla inicial de hiperparámetros
param_rf_smote1 = {
    "n_estimators": [200, 400, 600], #número de árboles del bosque
    "max_depth": [10, 20, 30], #profundidad máxima (nodos máximos de cada rama)
    "min_samples_split": [2, 5, 10], #nº mínimo de observaciones para crear un nuevo nodo
    "min_samples_leaf": [1, 2, 4],   #nº mínimo de observaciones que puede tener una hoja
    "max_features": ["sqrt", "log2"] #nº variables predictivas aleatoriamente usadas en cada árbol
}

# %% [markdown]
# Modificamos los valores de la rejilla de hiperparámetros en función de los resultados obtenidos

# %%
# Segundo grid de hiperparámetros
param_rf_smote2 = {
    "n_estimators":      [100, 200, 300, 400],
    "max_depth":         [20, 30, 40],
    "min_samples_split": [2, 3, 5],
    "min_samples_leaf":  [1, 2, 3],
    "max_features":      ["sqrt", "log2"]
}

# Entrenamiento Stage 2
resultado_rf_smote2 = ejecutar_random_search(
    modelo=rf,
    parametros=param_rf_smote2,
    x_train=x_train_SMOTE,
    y_train=y_train_SMOTE,
    nombre_modelo="Random Forest + SMOTE (Stage 2)",
    cv=cv,
    scoring=scoring,
    metricas=metricas,
    n_iter=10
)

# Mejor modelo final
best_rf_smote2 = resultado_rf_smote2["best_model"]
# Out:
# ======================================================================
# Entrenamiento: Random Forest + SMOTE (Stage 2)
# ======================================================================
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
#
# Métricas medias en validación cruzada:
# mean_test_Accuracy: 0.9455
# mean_test_F1: 0.9470
# mean_test_AUROC: 0.9889
# mean_test_Recall: 0.9735
# mean_test_BalancedAccuracy: 0.9455
#
# Mejores hiperparámetros:
# n_estimators: 300
# min_samples_split: 3
# min_samples_leaf: 1
# max_features: sqrt
# max_depth: 40

# %% [markdown]
# ### Undersampling

# %%
# Rejilla inicial de hiperparámetros
param_random_under1 = {
    "n_estimators": [200, 400, 600],
    "max_depth": [10, 20, 30],
    "min_samples_split": [2, 5, 10],
    "min_samples_leaf": [1, 2, 4],
    "max_features": ["sqrt", "log2"]
}

# Entrenamiento Stage 1
resultado_rf_under1 = ejecutar_random_search(
    modelo=rf,
    parametros=param_random_under1,
    x_train=x_train_UNDER,
    y_train=y_train_UNDER,
    nombre_modelo="Random Forest + Undersampling (Stage 1)",
    cv=cv,
    scoring=scoring,
    metricas=metricas,
    n_iter=50
)

# Mostramos los resultados obtenidos
best_rf_under1 = resultado_rf_under1["best_model"]
# Out:
# ======================================================================
# Entrenamiento: Random Forest + Undersampling (Stage 1)
# ======================================================================
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
#
# Métricas medias en validación cruzada:
# mean_test_Accuracy: 0.7991
# mean_test_F1: 0.8052
# mean_test_AUROC: 0.8439
# mean_test_Recall: 0.8338
# mean_test_BalancedAccuracy: 0.7988
#
# Mejores hiperparámetros:
# n_estimators: 200
# min_samples_split: 10
# min_samples_leaf: 4
# max_features: log2
# max_depth: 10

# %% [markdown]
# Modificamos los valores de la rejilla de hiperparámetros en función de los resultados obtenidos

# %%
# Segundo grid de hiperparámetros
param_random_under2 = {
    "n_estimators":      [100, 200, 300, 400],
    "max_depth":         [5, 10, 15, 20],
    "min_samples_split": [5, 10, 15],
    "min_samples_leaf":  [2, 4, 6],
    "max_features":      ["log2", "sqrt"]
}

# Entrenamiento Stage 2
resultado_rf_under2 = ejecutar_random_search(
    modelo=rf,
    parametros=param_random_under2,
    x_train=x_train_UNDER,
    y_train=y_train_UNDER,
    nombre_modelo="Random Forest + Undersampling (Stage 2)",
    cv=cv,
    scoring=scoring,
    metricas=metricas,
    n_iter=10
)

# Mejor modelo final
best_rf_under2 = resultado_rf_under2["best_model"]
# Out:
# ======================================================================
# Entrenamiento: Random Forest + Undersampling (Stage 2)
# ======================================================================
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
#
# Métricas medias en validación cruzada:
# mean_test_Accuracy: 0.7916
# mean_test_F1: 0.7994
# mean_test_AUROC: 0.8433
# mean_test_Recall: 0.8290
# mean_test_BalancedAccuracy: 0.7915
#
# Mejores hiperparámetros:
# n_estimators: 400
# min_samples_split: 5
# min_samples_leaf: 4
# max_features: log2
# max_depth: 5

# %% [markdown]
# ### Class - weights

# %%
# Random Forest con class - weight
rf_cw = RandomForestClassifier(
    class_weight="balanced", # penalizamos errores en stroke
    random_state=24
)

# %%
# Rejilla inicial de hiperparámetros
param_random_cw1 = {
    "n_estimators": [200, 400, 600],
    "max_depth": [10, 20, 30],
    "min_samples_split": [2, 5, 10],
    "min_samples_leaf": [1, 2, 4],
    "max_features": ["sqrt", "log2"]
}

# Entrenamiento Stage 1
resultado_rf_cw1 = ejecutar_random_search(
    modelo=rf_cw,
    parametros=param_random_cw1,
    x_train=x_train_desbal,
    y_train=y_train_desbal,
    nombre_modelo="Random Forest + Class Weights (Stage 1)",
    cv=cv,
    scoring=scoring,
    metricas=metricas,
    n_iter=50
)

# Mostramos los resultados obtenidos
best_rf_cw1 = resultado_rf_cw1["best_model"]
# Out:
# ======================================================================
# Entrenamiento: Random Forest + Class Weights (Stage 1)
# ======================================================================
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
#
# Métricas medias en validación cruzada:
# mean_test_Accuracy: 0.9029
# mean_test_F1: 0.2456
# mean_test_AUROC: 0.8380
# mean_test_Recall: 0.3268
# mean_test_BalancedAccuracy: 0.6296
#
# Mejores hiperparámetros:
# n_estimators: 200
# min_samples_split: 10
# min_samples_leaf: 4
# max_features: log2
# max_depth: 10

# %% [markdown]
# Acotamos la rejilla de hiperparámetros en función de los resultados

# %%
# Segundo grid de hiperparámetros
param_random_cw2 = {
    "n_estimators":      [100, 200, 300, 500],
    "max_depth":         [8, 10, 12, 15],
    "min_samples_split": [8, 10, 12, 15],
    "min_samples_leaf":  [3, 4, 5, 6],
    "max_features":      ["log2", "sqrt"]
}

# Entrenamiento Stage 2
resultado_rf_cw2 = ejecutar_random_search(
    modelo=rf_cw,
    parametros=param_random_cw2,
    x_train=x_train_desbal,
    y_train=y_train_desbal,
    nombre_modelo="Random Forest + Class Weights (Stage 2)",
    cv=cv,
    scoring=scoring,
    metricas=metricas,
    n_iter=10
)

# Mejor modelo final
best_rf_cw2 = resultado_rf_cw2["best_model"]
# Out:
# ======================================================================
# Entrenamiento: Random Forest + Class Weights (Stage 2)
# ======================================================================
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
#
# Métricas medias en validación cruzada:
# mean_test_Accuracy: 0.8995
# mean_test_F1: 0.2324
# mean_test_AUROC: 0.8401
# mean_test_Recall: 0.3165
# mean_test_BalancedAccuracy: 0.6229
#
# Mejores hiperparámetros:
# n_estimators: 200
# min_samples_split: 15
# min_samples_leaf: 4
# max_features: log2
# max_depth: 12

# %% [markdown]
# ### Undersampling + class weights

# %%
# Rejilla inicial de hiperparámetros
param_random_under_cw1 = {
    "n_estimators": [200, 400, 600],
    "max_depth": [10, 20, 30],
    "min_samples_split": [2, 5, 10],
    "min_samples_leaf": [1, 2, 4],
    "max_features": ["sqrt", "log2"]
}

# Entrenamiento Stage 1
resultado_rf_under_cw1 = ejecutar_random_search(
    modelo=rf_cw,
    parametros=param_random_under_cw1,
    x_train=x_train_UNDER,
    y_train=y_train_UNDER,
    nombre_modelo="Random Forest + Class Weights + Undersampling (Stage 1)",
    cv=cv,
    scoring=scoring,
    metricas=metricas,
    n_iter=50
)

# Mostramos los resultados obtenidos
best_rf_under_cw1 = resultado_rf_under_cw1["best_model"]
# Out:
# ======================================================================
# Entrenamiento: Random Forest + Class Weights + Undersampling (Stage 1)
# ======================================================================
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
#
# Métricas medias en validación cruzada:
# mean_test_Accuracy: 0.7966
# mean_test_F1: 0.8025
# mean_test_AUROC: 0.8445
# mean_test_Recall: 0.8288
# mean_test_BalancedAccuracy: 0.7963
#
# Mejores hiperparámetros:
# n_estimators: 400
# min_samples_split: 10
# min_samples_leaf: 4
# max_features: log2
# max_depth: 30

# %% [markdown]
# Ajustamos la rejilla de hiperparámetros en función de los resultados obtenidos

# %%
# Segunda rejilla de hiperparámetros
param_random_under_cw2 = {
    "n_estimators":      [300, 400, 500, 600],
    "max_depth":         [20, 30, 40, None],
    "min_samples_split": [8, 10, 12, 15],
    "min_samples_leaf":  [3, 4, 5, 6],
    "max_features":      ["log2", "sqrt"]
}

# Entrenamiento Stage 2
resultado_rf_under_cw2 = ejecutar_random_search(
    modelo=rf_cw,
    parametros=param_random_under_cw2,
    x_train=x_train_UNDER,
    y_train=y_train_UNDER,
    nombre_modelo="Random Forest + Class Weights + Undersampling (Stage 2)",
    cv=cv,
    scoring=scoring,
    metricas=metricas,
    n_iter=50
)

# Mejor modelo final
best_rf_under_cw2 = resultado_rf_under_cw2["best_model"]
# Out:
# ======================================================================
# Entrenamiento: Random Forest + Class Weights + Undersampling (Stage 2)
# ======================================================================
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
#
# Métricas medias en validación cruzada:
# mean_test_Accuracy: 0.7941
# mean_test_F1: 0.8008
# mean_test_AUROC: 0.8465
# mean_test_Recall: 0.8288
# mean_test_BalancedAccuracy: 0.7939
#
# Mejores hiperparámetros:
# n_estimators: 300
# min_samples_split: 12
# min_samples_leaf: 5
# max_features: sqrt
# max_depth: 40

# %% [markdown]
# ## XGBoost

# %%
from xgboost import XGBClassifier

# Definimos el modelo base
xgb = XGBClassifier(random_state=24, eval_metric="auc")

# %% [markdown]
# ### SMOTE

# %%
# Rejilla inicial de hiperparámetros
param_xgb_smote1 = {
    "n_estimators": [100, 300, 500],
    "learning_rate": [0.01, 0.1, 0.3],
    "max_depth": [3, 6, 9],
    "subsample": [0.6, 0.8, 1.0],
    "colsample_bytree": [0.6, 0.8, 1.0]
}

# Entrenamiento Stage 1
resultado_xgb_smote1 = ejecutar_random_search(
    modelo=xgb,
    parametros=param_xgb_smote1,
    x_train=x_train_SMOTE,
    y_train=y_train_SMOTE,
    nombre_modelo="XGBoost + SMOTE (Stage 1)",
    cv=cv,
    scoring=scoring,
    metricas=metricas,
    n_iter=50
)

# Mostramos los resultados obtenidos
best_xgb_smote1 = resultado_xgb_smote1["best_model"]
# Out:
# ======================================================================
# Entrenamiento: XGBoost + SMOTE (Stage 1)
# ======================================================================
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
#
# Métricas medias en validación cruzada:
# mean_test_Accuracy: 0.9490
# mean_test_F1: 0.9494
# mean_test_AUROC: 0.9912
# mean_test_Recall: 0.9586
# mean_test_BalancedAccuracy: 0.9490
#
# Mejores hiperparámetros:
# subsample: 0.8
# n_estimators: 300
# max_depth: 9
# learning_rate: 0.1
# colsample_bytree: 0.8

# %% [markdown]
# Ajustamos la rejilla de hiperparámetros en función de los valores obtenidos

# %%
# Rejilla inicial de hiperparámetros
param_xgb_smote2 = {
    "n_estimators":        [200, 300, 400, 500],
    "max_depth":           [7, 9, 11],
    "learning_rate":       [0.05, 0.1, 0.15, 0.2],
    "subsample":           [0.6, 0.8, 1.0],
    "colsample_bytree":    [0.6, 0.8, 1.0]
}

# Entrenamiento Stage 2
resultado_xgb_smote2 = ejecutar_random_search(
    modelo=xgb,
    parametros=param_xgb_smote2,
    x_train=x_train_SMOTE,
    y_train=y_train_SMOTE,
    nombre_modelo="XGBoost + SMOTE (Stage 2)",
    cv=cv,
    scoring=scoring,
    metricas=metricas,
    n_iter=10
)

# Mejor modelo final
best_xgb_smote2 = resultado_xgb_smote2["best_model"]
# Out:
# ======================================================================
# Entrenamiento: XGBoost + SMOTE (Stage 2)
# ======================================================================
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
#
# Métricas medias en validación cruzada:
# mean_test_Accuracy: 0.9482
# mean_test_F1: 0.9487
# mean_test_AUROC: 0.9913
# mean_test_Recall: 0.9568
# mean_test_BalancedAccuracy: 0.9482
#
# Mejores hiperparámetros:
# subsample: 1.0
# n_estimators: 500
# max_depth: 11
# learning_rate: 0.15
# colsample_bytree: 0.8

# %% [markdown]
# ### Undersampling

# %%
# Rejilla inicial de hiperparámetros
param_xgb_under1 = {
    "n_estimators": [100, 300, 500],
    "learning_rate": [0.01, 0.1, 0.3],
    "max_depth": [3, 6, 9],
    "subsample": [0.6, 0.8, 1.0],
    "colsample_bytree": [0.6, 0.8, 1.0]
}

# Entrenamiento Stage 1
resultado_xgb_under1 = ejecutar_random_search(
    modelo=xgb,
    parametros=param_xgb_under1,
    x_train=x_train_UNDER,
    y_train=y_train_UNDER,
    nombre_modelo="XGBoost + Undersampling (Stage 1)",
    cv=cv,
    scoring=scoring,
    metricas=metricas,
    n_iter=50
)

# Mostramos los resultados obternidos
best_xgb_under1 = resultado_xgb_under1["best_model"]
# Out:
# ======================================================================
# Entrenamiento: XGBoost + Undersampling (Stage 1)
# ======================================================================
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
#
# Métricas medias en validación cruzada:
# mean_test_Accuracy: 0.7966
# mean_test_F1: 0.8056
# mean_test_AUROC: 0.8421
# mean_test_Recall: 0.8440
# mean_test_BalancedAccuracy: 0.7964
#
# Mejores hiperparámetros:
# subsample: 0.6
# n_estimators: 100
# max_depth: 3
# learning_rate: 0.01
# colsample_bytree: 0.6

# %% [markdown]
# Redefinimos la rejilla de hiperparámetros en función de los resultados obtenidos

# %%
# Segunda rejilla de hiperparámetros
param_xgb_under2 = {
    "n_estimators":        [50, 100, 150, 200],
    "max_depth":           [2, 3, 4, 5],
    "learning_rate":       [0.005, 0.01, 0.02, 0.05],
    "subsample":           [0.5, 0.6, 0.7, 0.8],
    "colsample_bytree":    [0.5, 0.6, 0.7, 0.8]
}

# Entrenamiento Stage 2
resultado_xgb_under2 = ejecutar_random_search(
    modelo=xgb,
    parametros=param_xgb_under2,
    x_train=x_train_UNDER,
    y_train=y_train_UNDER,
    nombre_modelo="XGBoost + Undersampling (Stage 2)",
    cv=cv,
    scoring=scoring,
    metricas=metricas,
    n_iter=10
)

# Mejor modeo final
best_xgb_under2 = resultado_xgb_under2["best_model"]
# Out:
# ======================================================================
# Entrenamiento: XGBoost + Undersampling (Stage 2)
# ======================================================================
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
#
# Métricas medias en validación cruzada:
# mean_test_Accuracy: 0.8016
# mean_test_F1: 0.8094
# mean_test_AUROC: 0.8440
# mean_test_Recall: 0.8440
# mean_test_BalancedAccuracy: 0.8014
#
# Mejores hiperparámetros:
# subsample: 0.6
# n_estimators: 50
# max_depth: 3
# learning_rate: 0.02
# colsample_bytree: 0.6

# %% [markdown]
# ### scale_pos_weight

# %%
# Definimos el modelo base con scale_pos_weight
xgb_cw = XGBClassifier(
    scale_pos_weight=scale,
    random_state=24,
    eval_metric="auc"
)

# %%
# Rejilla inicial de hiperparámetros
param_xgb_cw1 = {
    "n_estimators": [100, 300, 500],
    "learning_rate": [0.01, 0.1, 0.3],
    "max_depth": [3, 6, 9],
    "subsample": [0.6, 0.8, 1.0],
    "colsample_bytree": [0.6, 0.8, 1.0]
}

# Entrenamiento Stage 1
resultado_xgb_cw1 = ejecutar_random_search(
    modelo=xgb_cw,
    parametros=param_xgb_cw1,
    x_train=x_train_desbal,
    y_train=y_train_desbal,
    nombre_modelo="XGBoost + Class Weights (Stage 1)",
    cv=cv,
    scoring=scoring,
    metricas=metricas,
    n_iter=50
)

# Mostramos los resultados obtenidos
best_xgb_cw1 = resultado_xgb_cw1["best_model"]
# Out:
# ======================================================================
# Entrenamiento: XGBoost + Class Weights (Stage 1)
# ======================================================================
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
#
# Métricas medias en validación cruzada:
# mean_test_Accuracy: 0.7659
# mean_test_F1: 0.2491
# mean_test_AUROC: 0.8469
# mean_test_Recall: 0.7992
# mean_test_BalancedAccuracy: 0.7817
#
# Mejores hiperparámetros:
# subsample: 0.6
# n_estimators: 300
# max_depth: 3
# learning_rate: 0.01
# colsample_bytree: 0.8

# %% [markdown]
# Ajustamos la rejilla de hiperparámetros en función de los resultados obtenidos

# %%
# Segunda rejilla de hiperparámetros
param_xgb_cw2 = {
    "n_estimators":        [200, 300, 400, 500],
    "max_depth":           [2, 3, 4, 5],
    "learning_rate":       [0.005, 0.01, 0.02, 0.05],
    "subsample":           [0.5, 0.6, 0.7, 0.8],
    "colsample_bytree":    [0.6, 0.8, 1.0]
}

# Entrenamiento Stage 2
resultado_xgb_cw2 = ejecutar_random_search(
    modelo=xgb_cw,
    parametros=param_xgb_cw2,
    x_train=x_train_desbal,
    y_train=y_train_desbal,
    nombre_modelo="XGBoost + Class Weights (Stage 2)",
    cv=cv,
    scoring=scoring,
    metricas=metricas,
    n_iter=10
)

# Mejor modelo final
best_xgb_cw2 = resultado_xgb_cw2["best_model"]
# Out:
# ======================================================================
# Entrenamiento: XGBoost + Class Weights (Stage 2)
# ======================================================================
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
#
# Métricas medias en validación cruzada:
# mean_test_Accuracy: 0.7348
# mean_test_F1: 0.2288
# mean_test_AUROC: 0.8471
# mean_test_Recall: 0.8092
# mean_test_BalancedAccuracy: 0.7701
#
# Mejores hiperparámetros:
# subsample: 0.7
# n_estimators: 500
# max_depth: 2
# learning_rate: 0.01
# colsample_bytree: 0.8

# %% [markdown]
# ### Undersampling + scale_pos_weight

# %%
# Rejilla inicial de hiperparámetros
param_xgb_under_cw1 = {
    "n_estimators": [100, 300, 500],
    "learning_rate": [0.01, 0.1, 0.3],
    "max_depth": [3, 6, 9],
    "subsample": [0.6, 0.8, 1.0],
    "colsample_bytree": [0.6, 0.8, 1.0]
}

# Entrenamiento Stage 1
resultado_xgb_under_cw1 = ejecutar_random_search(
    modelo=xgb_cw,
    parametros=param_xgb_under_cw1,
    x_train=x_train_UNDER,
    y_train=y_train_UNDER,
    nombre_modelo="XGBoost + Undersampling + scale_pos_weight (Stage 1)",
    cv=cv,
    scoring=scoring,
    metricas=metricas,
    n_iter=50
)

# Mostramos los resultados obtenidos
best_xgb_under_cw1 = resultado_xgb_under_cw1["best_model"]
# Out:
# ======================================================================
# Entrenamiento: XGBoost + Undersampling + scale_pos_weight (Stage 1)
# ======================================================================
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
#
# Métricas medias en validación cruzada:
# mean_test_Accuracy: 0.6862
# mean_test_F1: 0.7536
# mean_test_AUROC: 0.8533
# mean_test_Recall: 0.9547
# mean_test_BalancedAccuracy: 0.6860
#
# Mejores hiperparámetros:
# subsample: 0.6
# n_estimators: 300
# max_depth: 3
# learning_rate: 0.01
# colsample_bytree: 0.8

# %% [markdown]
# Ajustamos la rejilla de hiperparámetos en función de los resultados obtenidos

# %%
# Segunda rejilla de hiperparámetros
param_xgb_under_cw2 = {
    "n_estimators":        [250, 300, 350, 400, 500],
    "max_depth":           [2, 3, 4, 5],
    "learning_rate":       [0.005, 0.01, 0.02, 0.03],
    "subsample":           [0.4, 0.5, 0.6, 0.7, 0.8],
    "colsample_bytree":    [0.6, 0.7, 0.8, 0.9, 1.0]
}

# Entrenamiento Stage 2
resultado_xgb_under_cw2 = ejecutar_random_search(
    modelo=xgb_cw,
    parametros=param_xgb_under_cw2,
    x_train=x_train_UNDER,
    y_train=y_train_UNDER,
    nombre_modelo="XGBoost + Undersampling + scale_pos_weight (Stage 2)",
    cv=cv,
    scoring=scoring,
    metricas=metricas,
    n_iter=10
)

# Moejor modelo final
best_xgb_under_cw2 = resultado_xgb_under_cw2["best_model"]
# Out:
# ======================================================================
# Entrenamiento: XGBoost + Undersampling + scale_pos_weight (Stage 2)
# ======================================================================
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
#
# Métricas medias en validación cruzada:
# mean_test_Accuracy: 0.6736
# mean_test_F1: 0.7511
# mean_test_AUROC: 0.8493
# mean_test_Recall: 0.9799
# mean_test_BalancedAccuracy: 0.6735
#
# Mejores hiperparámetros:
# subsample: 0.7
# n_estimators: 500
# max_depth: 2
# learning_rate: 0.01
# colsample_bytree: 0.6

# %% [markdown]
# ## SVM

# %%
from sklearn.svm import SVC

# Definimos el modelo base
svm = SVC(random_state=24, probability=True)

# %% [markdown]
# ### SMOTE

# %%
# Rejilla inicial de hiperparámetros
param_svm_smote1 = {
    "C": [0.1, 1, 10, 100],
    "gamma": ["scale", "auto", 0.001, 0.01, 0.1],
    "kernel": ["rbf", "linear"]
}

# Emtrenamiento Stage 1
resultado_svm_smote1 = ejecutar_random_search(
    modelo=svm,
    parametros=param_svm_smote1,
    x_train=x_train_SMOTE,
    y_train=y_train_SMOTE,
    nombre_modelo="SVM + SMOTE (Stage 1)",
    cv=cv,
    scoring=scoring,
    metricas=metricas,
    n_iter=40
)

# Mostamos los resultados obtenidos
best_svm_smote1 = resultado_svm_smote1["best_model"]
# Out:
# ======================================================================
# Entrenamiento: SVM + SMOTE (Stage 1)
# ======================================================================
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
#
# Métricas medias en validación cruzada:
# mean_test_Accuracy: 0.8979
# mean_test_F1: 0.9017
# mean_test_AUROC: 0.9624
# mean_test_Recall: 0.9360
# mean_test_BalancedAccuracy: 0.8979
#
# Mejores hiperparámetros:
# kernel: rbf
# gamma: scale
# C: 100

# %%
# Segunda rejilla de hiperparámetros
param_svm_smote2 = {
    "C":      [10, 50, 100, 200, 500],
    "gamma":  ["scale", 0.001, 0.005, 0.01, 0.05],
    "kernel": ["rbf"]
}

# Entrenamiento Stage 2
resultado_svm_smote2 = ejecutar_random_search(
    modelo=svm,
    parametros=param_svm_smote2,
    x_train=x_train_SMOTE,
    y_train=y_train_SMOTE,
    nombre_modelo="SVM + SMOTE (Stage 2)",
    cv=cv,
    scoring=scoring,
    metricas=metricas,
    n_iter=10
)

# Mejor modelo final
best_svm_smote2 = resultado_svm_smote2["best_model"]
# Out:
# ======================================================================
# Entrenamiento: SVM + SMOTE (Stage 2)
# ======================================================================
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
#
# Métricas medias en validación cruzada:
# mean_test_Accuracy: 0.8979
# mean_test_F1: 0.9017
# mean_test_AUROC: 0.9624
# mean_test_Recall: 0.9360
# mean_test_BalancedAccuracy: 0.8979
#
# Mejores hiperparámetros:
# kernel: rbf
# gamma: scale
# C: 100

# %% [markdown]
# ### Undersampling

# %%
# Rejilla inicial de hiperparámetros
param_svm_under1 = {
    "C": [0.1, 1, 10, 100],
    "gamma": ["scale", "auto", 0.001, 0.01, 0.1],
    "kernel": ["rbf", "linear"]
}

# Entrenamiento Stage 1
resultado_svm_under1 = ejecutar_random_search(
    modelo=svm,
    parametros=param_svm_under1,
    x_train=x_train_UNDER,
    y_train=y_train_UNDER,
    nombre_modelo="SVM + Undersampling (Stage 1)",
    cv=cv,
    scoring=scoring,
    metricas=metricas,
    n_iter=40
)

#Mostramos los resultados obtenidos
best_svm_under1 = resultado_svm_under1["best_model"]
# Out:
# ======================================================================
# Entrenamiento: SVM + Undersampling (Stage 1)
# ======================================================================
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
#
# Métricas medias en validación cruzada:
# mean_test_Accuracy: 0.7540
# mean_test_F1: 0.7650
# mean_test_AUROC: 0.8318
# mean_test_Recall: 0.7990
# mean_test_BalancedAccuracy: 0.7540
#
# Mejores hiperparámetros:
# kernel: linear
# gamma: scale
# C: 100

# %% [markdown]
# Variamos la rejilla de hiperparámetros en función de los resultados obtenidos

# %%
#Segunda rejilla de hiperparámetros
param_svm_under2 = {
    "C":      [10, 50, 100, 200, 500],
    "kernel": ["linear"],
    "gamma":  ["scale"]
}

# Entrenamiento Stage 2
resultado_svm_under2 = ejecutar_random_search(
    modelo=svm,
    parametros=param_svm_under2,
    x_train=x_train_UNDER,
    y_train=y_train_UNDER,
    nombre_modelo="SVM + Undersampling (Stage 2)",
    cv=cv,
    scoring=scoring,
    metricas=metricas,
    n_iter=10
)

# Mejor modelo final
best_svm_under2 = resultado_svm_under2["best_model"]
# Out:
# ======================================================================
# Entrenamiento: SVM + Undersampling (Stage 2)
# ======================================================================
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_search.py:318: UserWarning: The total space of parameters 5 is smaller than n_iter=10. Running 5 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Métricas medias en validación cruzada:
# mean_test_Accuracy: 0.7540
# mean_test_F1: 0.7650
# mean_test_AUROC: 0.8319
# mean_test_Recall: 0.7990
# mean_test_BalancedAccuracy: 0.7540
#
# Mejores hiperparámetros:
# kernel: linear
# gamma: scale
# C: 200

# %% [markdown]
# ### Class-weights

# %%
# Definimos el modelo base
svm_cw = SVC(random_state=24, probability=True, class_weight="balanced")

# %%
# Rejilla inicial de hiperparámetros
param_svm_cw1 = {
    "C": [0.1, 1, 10, 100],
    "gamma": ["scale", "auto", 0.001, 0.01, 0.1],
    "kernel": ["rbf", "linear"]
}

# Entrenamiento Stage 1
resultado_svm_cw1 = ejecutar_random_search(
    modelo=svm_cw,
    parametros=param_svm_cw1,
    x_train=x_train_desbal,
    y_train=y_train_desbal,
    nombre_modelo="SVM + Class Weights (Stage 1)",
    cv=cv,
    scoring=scoring,
    metricas=metricas,
    n_iter=10
)

# Mostramos los resultados obtenidos
best_svm_cw1 = resultado_svm_cw1["best_model"]
# Out:
# ======================================================================
# Entrenamiento: SVM + Class Weights (Stage 1)
# ======================================================================
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
#
# Métricas medias en validación cruzada:
# mean_test_Accuracy: 0.7378
# mean_test_F1: 0.2332
# mean_test_AUROC: 0.8473
# mean_test_Recall: 0.8191
# mean_test_BalancedAccuracy: 0.7764
#
# Mejores hiperparámetros:
# kernel: linear
# gamma: scale
# C: 100

# %% [markdown]
# Variamos la rejilla de hipeparámetros en función de los resultados obtenidos

# %%
# Segunda rejilla de hiperparámetros
param_svm_cw2 = {
    "C":      [50, 100, 150, 200, 300],
    "kernel": ["linear"],
    "gamma":  ["scale"]
}

# Entrenamiento Stage 2
resultado_svm_cw2 = ejecutar_random_search(
    modelo=svm_cw,
    parametros=param_svm_cw2,
    x_train=x_train_desbal,
    y_train=y_train_desbal,
    nombre_modelo="SVM + Class Weights (Stage 2)",
    cv=cv,
    scoring=scoring,
    metricas=metricas,
    n_iter=10
)

# Mejor modelo final
best_svm_cw2 = resultado_svm_cw2["best_model"]
# Out:
# ======================================================================
# Entrenamiento: SVM + Class Weights (Stage 2)
# ======================================================================
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_search.py:318: UserWarning: The total space of parameters 5 is smaller than n_iter=10. Running 5 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Métricas medias en validación cruzada:
# mean_test_Accuracy: 0.7375
# mean_test_F1: 0.2330
# mean_test_AUROC: 0.8473
# mean_test_Recall: 0.8191
# mean_test_BalancedAccuracy: 0.7762
#
# Mejores hiperparámetros:
# kernel: linear
# gamma: scale
# C: 300

# %% [markdown]
# ### Undersampling + class_weights

# %%
# Rejilla inicial de hiperparámetros
param_svm_under_cw1 = {
    "C": [0.1, 1, 10, 100],
    "gamma": ["scale", "auto", 0.001, 0.01, 0.1],
    "kernel": ["rbf", "linear"]
}

# Entrenamiento Stage 1
resultado_svm_under_cw1 = ejecutar_random_search(
    modelo=svm_cw,
    parametros=param_svm_under_cw1,
    x_train=x_train_UNDER,
    y_train=y_train_UNDER,
    nombre_modelo="SVM + Undersampling + Class Weights (Stage 1)",
    cv=cv,
    scoring=scoring,
    metricas=metricas,
    n_iter=10
)

# Mostramos el resultado obtenido
best_svm_under_cw1 = resultado_svm_under_cw1["best_model"]
# Out:
# ======================================================================
# Entrenamiento: SVM + Undersampling + Class Weights (Stage 1)
# ======================================================================
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
#
# Métricas medias en validación cruzada:
# mean_test_Accuracy: 0.7540
# mean_test_F1: 0.7650
# mean_test_AUROC: 0.8316
# mean_test_Recall: 0.7990
# mean_test_BalancedAccuracy: 0.7540
#
# Mejores hiperparámetros:
# kernel: linear
# gamma: scale
# C: 100

# %% [markdown]
# Ajustamos los hiperparámetros en función de los resultados obtenidos

# %%
# Segunda rejilla de hiperparámetros
param_svm_under_cw2 = {
    "C":      [75, 100, 125, 150, 200],
    "kernel": ["linear"],
    "gamma":  ["scale"]
}

# Entrenamiento Stage 2
resultado_svm_under_cw2 = ejecutar_random_search(
    modelo=svm_cw,
    parametros=param_svm_under_cw2,
    x_train=x_train_UNDER,
    y_train=y_train_UNDER,
    nombre_modelo="SVM + Undersampling + Class Weights (Stage 1)",
    cv=cv,
    scoring=scoring,
    metricas=metricas,
    n_iter=10
)

# Mejor modelo final
best_svm_under_cw2 = resultado_svm_under_cw2["best_model"]
# Out:
# ======================================================================
# Entrenamiento: SVM + Undersampling + Class Weights (Stage 1)
# ======================================================================
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_search.py:318: UserWarning: The total space of parameters 5 is smaller than n_iter=10. Running 5 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Métricas medias en validación cruzada:
# mean_test_Accuracy: 0.7540
# mean_test_F1: 0.7650
# mean_test_AUROC: 0.8322
# mean_test_Recall: 0.7990
# mean_test_BalancedAccuracy: 0.7540
#
# Mejores hiperparámetros:
# kernel: linear
# gamma: scale
# C: 75

# %% [markdown]
# ## Regresión logística

# %%
from sklearn.linear_model import LogisticRegression

# Definimos el modelo base
lr = LogisticRegression(random_state=24, max_iter=1000)

# Evitamos warnings en las combinaciones incorrectas entre penalty y solver
import warnings
from sklearn.exceptions import ConvergenceWarning
warnings.filterwarnings("ignore", category=ConvergenceWarning)

# %% [markdown]
# ### SMOTE

# %%
# Rejilla inicial de hiperparámetros
param_lr_smote1 = {
    "C": [0.01, 0.1, 1, 10, 100],
    "penalty": ["l1", "l2"],
    "solver": ["liblinear", "saga", "lbfgs"]
}

# Entrenamiento Stage 1
resultado_lr_smote1 = ejecutar_random_search(
    modelo=lr,
    parametros=param_lr_smote1,
    x_train=x_train_SMOTE,
    y_train=y_train_SMOTE,
    nombre_modelo="Logistic Regression + SMOTE (Stage 1)",
    cv=cv,
    scoring=scoring,
    metricas=metricas,
    n_iter=50
)

# Mostramos los resultados obtenidos
best_lr_smote1 = resultado_lr_smote1["best_model"]
# Out:
# ======================================================================
# Entrenamiento: Logistic Regression + SMOTE (Stage 1)
# ======================================================================
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_search.py:318: UserWarning: The total space of parameters 30 is smaller than n_iter=50. Running 30 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py:547: FitFailedWarning:
# 25 fits failed out of a total of 150.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 25 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/base.py", line 1474, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py", line 1172, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py", line 67, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or None penalties, got l1 penalty.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_search.py:1051: UserWarning: One or more of the test scores are non-finite: [0.89894095 0.85702508        nan 0.87039732 0.85394223 0.8541993
#  0.85214076 0.84776991        nan 0.8577986  0.85291296 0.8534271
#  0.83748449 0.83697035        nan 0.84108446 0.83954138 0.83979878
#  0.83619881 0.83645588        nan 0.83697002 0.83645588 0.83722709
#  0.83671295 0.83671295        nan 0.83645588 0.83645588 0.83619881]
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_search.py:1051: UserWarning: One or more of the test scores are non-finite: [0.81050391 0.80476268        nan 0.79192956 0.79387378 0.7939233
#  0.80661008 0.80629087        nan 0.80755258 0.80735254 0.80764039
#  0.80219629 0.80190082        nan 0.80377027 0.80337293 0.80352661
#  0.80165588 0.80190175        nan 0.80199689 0.80170281 0.80214734
#  0.80195242 0.80204993        nan 0.80190403 0.80190403 0.80166128]
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_search.py:1051: UserWarning: One or more of the test scores are non-finite: [0.85111161 0.85123086        nan 0.83642151 0.84191618 0.84190229
#  0.86000938 0.86025256        nan 0.8589875  0.85911686 0.85913274
#  0.86086749 0.86082888        nan 0.86074679 0.86069004 0.86073962
#  0.86066771 0.86066706        nan 0.86069447 0.86067895 0.86062572
#  0.86067037 0.86066773        nan 0.86067533 0.860675   0.86061284]
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_search.py:1051: UserWarning: One or more of the test scores are non-finite: [0.78979335 0.79210599        nan 0.7712794  0.7782225  0.7782225
#  0.79570678 0.7963492         nan 0.79557816 0.79647831 0.79673538
#  0.79352127 0.79326412        nan 0.79467858 0.79454988 0.7946785
#  0.79313559 0.79339265        nan 0.79339265 0.79313559 0.79352119
#  0.79339265 0.79352119        nan 0.79339265 0.79339265 0.79313567]
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_search.py:1051: UserWarning: One or more of the test scores are non-finite: [0.78979332 0.79210413        nan 0.77127886 0.77822288 0.77822288
#  0.79570459 0.7963476         nan 0.79557639 0.79647696 0.79673403
#  0.79351917 0.7932621         nan 0.79467615 0.79454745 0.79467615
#  0.7931334  0.79339047        nan 0.79339047 0.7931334  0.79351901
#  0.79339047 0.79351901        nan 0.79339047 0.79339047 0.7931334 ]
#   warnings.warn(
# Métricas medias en validación cruzada:
# mean_test_Accuracy: 0.7935
# mean_test_F1: 0.8022
# mean_test_AUROC: 0.8609
# mean_test_Recall: 0.8375
# mean_test_BalancedAccuracy: 0.7935
#
# Mejores hiperparámetros:
# solver: liblinear
# penalty: l1
# C: 1

# %% [markdown]
# Variamos los hiperparámetros en función del resultado

# %%
# Segunda rejilla de hiperparámetros
param_lr_smote2 = {
    "C":       [0.5, 1, 2, 5, 10],
    "penalty": ["l1"],
    "solver":  ["liblinear"]
}

# Entrenamiento Stage 2
resultado_lr_smote2 = ejecutar_random_search(
    modelo=lr,
    parametros=param_lr_smote2,
    x_train=x_train_SMOTE,
    y_train=y_train_SMOTE,
    nombre_modelo="Logistic Regression + SMOTE (Stage 2)",
    cv=cv,
    scoring=scoring,
    metricas=metricas,
    n_iter=5
)

# Mejor modelo final
best_lr_smote2 = resultado_lr_smote2["best_model"]
# Out:
# ======================================================================
# Entrenamiento: Logistic Regression + SMOTE (Stage 2)
# ======================================================================
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
#
# Métricas medias en validación cruzada:
# mean_test_Accuracy: 0.7942
# mean_test_F1: 0.8030
# mean_test_AUROC: 0.8610
# mean_test_Recall: 0.8390
# mean_test_BalancedAccuracy: 0.7942
#
# Mejores hiperparámetros:
# solver: liblinear
# penalty: l1
# C: 0.5

# %% [markdown]
# ### Undersampling

# %%
# Rejilla inicial de hiperparámetros
param_lr_under1 = {
    "C": [0.01, 0.1, 1, 10, 100],
    "penalty": ["l1", "l2"],
    "solver": ["liblinear", "saga", "lbfgs"]
}

# Entrenamiento Stage 1
resultado_lr_under1 = ejecutar_random_search(
    modelo=lr,
    parametros=param_lr_under1,
    x_train=x_train_UNDER,
    y_train=y_train_UNDER,
    nombre_modelo="Logistic Regression + Undersampling (Stage 1)",
    cv=cv,
    scoring=scoring,
    metricas=metricas,
    n_iter=50
)
# Mostramos los resultados obtenidos
best_lr_under1 = resultado_lr_under1["best_model"]
# Out:
# ======================================================================
# Entrenamiento: Logistic Regression + Undersampling (Stage 1)
# ======================================================================
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_search.py:318: UserWarning: The total space of parameters 30 is smaller than n_iter=50. Running 30 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Métricas medias en validación cruzada:
# mean_test_Accuracy: 0.7665
# mean_test_F1: 0.7749
# mean_test_AUROC: 0.8344
# mean_test_Recall: 0.8040
# mean_test_BalancedAccuracy: 0.7664
#
# Mejores hiperparámetros:
# solver: saga
# penalty: l1
# C: 1
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py:547: FitFailedWarning:
# 25 fits failed out of a total of 150.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 25 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/base.py", line 1474, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py", line 1172, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py", line 67, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or None penalties, got l1 penalty.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_search.py:1051: UserWarning: One or more of the test scores are non-finite: [0.         0.                nan 0.90987179 0.73858974 0.73858974
#  0.91961538 0.83935897        nan 0.78884615 0.77858974 0.77858974
#  0.80397436 0.80397436        nan 0.80897436 0.80884615 0.80884615
#  0.79884615 0.79884615        nan 0.79884615 0.79884615 0.79884615
#  0.78884615 0.78884615        nan 0.78884615 0.78884615 0.78884615]
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_search.py:1051: UserWarning: One or more of the test scores are non-finite: [0.         0.                nan 0.735269   0.70405686 0.70405686
#  0.77214574 0.77581342        nan 0.73597746 0.74483995 0.74483995
#  0.77125282 0.7748787         nan 0.77273287 0.77239764 0.77239764
#  0.76822021 0.76822021        nan 0.76822021 0.76822021 0.76822021
#  0.76438157 0.76438157        nan 0.76240626 0.76240626 0.76240626]
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_search.py:1051: UserWarning: One or more of the test scores are non-finite: [0.5        0.5               nan 0.74334936 0.75858974 0.75846474
#  0.81705449 0.83005128        nan 0.77831731 0.78846795 0.78872115
#  0.8315     0.83440385        nan 0.81645513 0.81530449 0.81542949
#  0.82377244 0.82390385        nan 0.82340705 0.82340385 0.82315385
#  0.82176923 0.82176603        nan 0.82201923 0.82164103 0.82188782]
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_search.py:1051: UserWarning: One or more of the test scores are non-finite: [0.5        0.5               nan 0.67098101 0.68860759 0.68860759
#  0.72655063 0.75661392        nan 0.71617089 0.73370253 0.73370253
#  0.76148734 0.76648734        nan 0.76148734 0.7614557  0.7614557
#  0.7589557  0.7589557         nan 0.7589557  0.7589557  0.7589557
#  0.75648734 0.75648734        nan 0.7539557  0.7539557  0.7539557 ]
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_search.py:1051: UserWarning: One or more of the test scores are non-finite: [0.5        0.5               nan 0.67089744 0.68852564 0.68852564
#  0.72634615 0.75647436        nan 0.71602564 0.73346154 0.73346154
#  0.76147436 0.76641026        nan 0.76141026 0.76134615 0.76134615
#  0.75884615 0.75884615        nan 0.75884615 0.75884615 0.75884615
#  0.75641026 0.75641026        nan 0.75384615 0.75384615 0.75384615]
#   warnings.warn(

# %%
# Segunda rejilla de hiperparámetros
param_lr_under2 = {
    "C":       [0.5, 1, 2, 5, 10],
    "penalty": ["l1"],
    "solver":  ["saga"]
}

# Entrenamiento Stage 2
resultado_lr_under2 = ejecutar_random_search(
    modelo=lr,
    parametros=param_lr_under2,
    x_train=x_train_UNDER,
    y_train=y_train_UNDER,
    nombre_modelo="Logistic Regression + Undersampling (Stage 2)",
    cv=cv,
    scoring=scoring,
    metricas=metricas,
    n_iter=5
)
# Mejor modelo final
best_lr_under2 = resultado_lr_under2["best_model"]
# Out:
# ======================================================================
# Entrenamiento: Logistic Regression + Undersampling (Stage 2)
# ======================================================================
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
#
# Métricas medias en validación cruzada:
# mean_test_Accuracy: 0.7640
# mean_test_F1: 0.7751
# mean_test_AUROC: 0.8405
# mean_test_Recall: 0.8141
# mean_test_BalancedAccuracy: 0.7640
#
# Mejores hiperparámetros:
# solver: saga
# penalty: l1
# C: 0.5

# %% [markdown]
# ### Class_weight

# %%
# Definimos el modelo base
lr_cw = LogisticRegression(random_state=24, max_iter=1000, class_weight="balanced")

# %%
# Rejilla inicial de hiperparámetros
param_lr_cw1 = {
    "C": [0.01, 0.1, 1, 10, 100],
    "penalty": ["l1", "l2"],
    "solver": ["liblinear", "saga", "lbfgs"]
}

# Entrenamiento Stage 1
resultado_lr_cw1 = ejecutar_random_search(
    modelo=lr_cw,
    parametros=param_lr_cw1,
    x_train=x_train_desbal,
    y_train=y_train_desbal,
    nombre_modelo="Logistic Regression + Class Weight (Stage 1)",
    cv=cv,
    scoring=scoring,
    metricas=metricas,
    n_iter=50
)

# Mostramos los resultados obtenidos
best_lr_cw1 = resultado_lr_cw1["best_model"]
# Out:
# ======================================================================
# Entrenamiento: Logistic Regression + Class Weight (Stage 1)
# ======================================================================
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_search.py:318: UserWarning: The total space of parameters 30 is smaller than n_iter=50. Running 30 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Métricas medias en validación cruzada:
# mean_test_Accuracy: 0.7361
# mean_test_F1: 0.2310
# mean_test_AUROC: 0.8484
# mean_test_Recall: 0.8141
# mean_test_BalancedAccuracy: 0.7731
#
# Mejores hiperparámetros:
# solver: liblinear
# penalty: l1
# C: 0.1
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py:547: FitFailedWarning:
# 25 fits failed out of a total of 150.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 25 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/base.py", line 1474, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py", line 1172, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py", line 67, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or None penalties, got l1 penalty.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_search.py:1051: UserWarning: One or more of the test scores are non-finite: [0.92948718 0.84              nan 0.83423077 0.54076923 0.79397436
#  0.81410256 0.79935897        nan 0.81910256 0.61615385 0.81910256
#  0.79410256 0.75987179        nan 0.79910256 0.6        0.79410256
#  0.79910256 0.37538462        nan 0.79410256 0.55423077 0.79410256
#  0.79910256 0.44051282        nan 0.79910256 0.73961538 0.79910256]
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_search.py:1051: UserWarning: One or more of the test scores are non-finite: [0.18563314 0.17619043        nan 0.19992547 0.17420068 0.21271848
#  0.23097958 0.1983091         nan 0.23143123 0.20533417 0.23455267
#  0.23500756 0.20356548        nan 0.23517334 0.15686247 0.23390886
#  0.23674023 0.13054844        nan 0.23532945 0.20721048 0.23514512
#  0.23636435 0.14384929        nan 0.23636435 0.18680991 0.23636435]
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_search.py:1051: UserWarning: One or more of the test scores are non-finite: [0.8371751  0.82008863        nan 0.81321191 0.80660548 0.82335894
#  0.84836946 0.82473641        nan 0.84463976 0.81140684 0.84569863
#  0.84651329 0.81152467        nan 0.84691076 0.82135603 0.84673034
#  0.84607768 0.79775249        nan 0.8460569  0.78292134 0.84608835
#  0.84596083 0.78426514        nan 0.84596741 0.82010423 0.84609581]
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_search.py:1051: UserWarning: One or more of the test scores are non-finite: [0.60273438 0.50009068        nan 0.67343702 0.76915934 0.71330498
#  0.73605564 0.67558903        nan 0.73483045 0.7600668  0.73947802
#  0.74804087 0.6741346         nan 0.74681718 0.73604397 0.74657238
#  0.74901856 0.81904247        nan 0.74852897 0.78932495 0.74828447
#  0.74852927 0.78750213        nan 0.74852927 0.66409369 0.74852927]
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_search.py:1051: UserWarning: One or more of the test scores are non-finite: [0.75774482 0.66141944        nan 0.74971605 0.66073938 0.75157274
#  0.77308007 0.7343296         nan 0.77480853 0.69172489 0.77725152
#  0.76989423 0.71486988        nan 0.77162253 0.671394   0.76912269
#  0.77277984 0.60851394        nan 0.7701513  0.67784424 0.77002277
#  0.77252277 0.62282578        nan 0.77252277 0.69997282 0.77252277]
#   warnings.warn(

# %% [markdown]
# Ajustamos los hiperparámetros en función de los resultados obtenidos

# %%
# Segunda rejilla de hiperparámetros
param_lr_cw2 = {
    "C":       [0.01, 0.05, 0.1, 0.5, 1],
    "penalty": ["l1"],
    "solver":  ["liblinear"]
}

# Entrenamiento Stage 2
resultado_lr_cw2 = ejecutar_random_search(
    modelo=lr_cw,
    parametros=param_lr_cw2,
    x_train=x_train_desbal,
    y_train=y_train_desbal,
    nombre_modelo="Logistic Regression + Class Weight (Stage 2)",
    cv=cv,
    scoring=scoring,
    metricas=metricas,
    n_iter=5
)

# Mejor modelo final
best_lr_cw2 = resultado_lr_cw2["best_model"]
# Out:
# ======================================================================
# Entrenamiento: Logistic Regression + Class Weight (Stage 2)
# ======================================================================
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
#
# Métricas medias en validación cruzada:
# mean_test_Accuracy: 0.7361
# mean_test_F1: 0.2310
# mean_test_AUROC: 0.8484
# mean_test_Recall: 0.8141
# mean_test_BalancedAccuracy: 0.7731
#
# Mejores hiperparámetros:
# solver: liblinear
# penalty: l1
# C: 0.1

# %% [markdown]
# ### Undersampling + class_weight

# %%
# Rejilla inicial de hiperparámetros
param_lr_under_cw1 = {
    "C": [0.01, 0.1, 1, 10, 100],
    "penalty": ["l1", "l2"],
    "solver": ["liblinear", "saga", "lbfgs"]
}

# Entrenamiento Stage 1
resultado_lr_under_cw1 = ejecutar_random_search(
    modelo=lr_cw,
    parametros=param_lr_under_cw1,
    x_train=x_train_UNDER,
    y_train=y_train_UNDER,
    nombre_modelo="Logistic Regression + Under + CW (Stage 1)",
    cv=cv,
    scoring=scoring,
    metricas=metricas,
    n_iter=50
)

# Mostramos los resultados obtenidos
best_lr_under_cw1 = resultado_lr_under_cw1["best_model"]
# Out:
# ======================================================================
# Entrenamiento: Logistic Regression + Under + CW (Stage 1)
# ======================================================================
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_search.py:318: UserWarning: The total space of parameters 30 is smaller than n_iter=50. Running 30 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Métricas medias en validación cruzada:
# mean_test_Accuracy: 0.7665
# mean_test_F1: 0.7749
# mean_test_AUROC: 0.8344
# mean_test_Recall: 0.8040
# mean_test_BalancedAccuracy: 0.7664
#
# Mejores hiperparámetros:
# solver: saga
# penalty: l1
# C: 1
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py:547: FitFailedWarning:
# 25 fits failed out of a total of 150.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 25 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/base.py", line 1474, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py", line 1172, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py", line 67, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or None penalties, got l1 penalty.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_search.py:1051: UserWarning: One or more of the test scores are non-finite: [0.         0.                nan 0.90974359 0.73858974 0.73858974
#  0.91961538 0.83935897        nan 0.78884615 0.77858974 0.77858974
#  0.80397436 0.80397436        nan 0.80897436 0.80884615 0.80884615
#  0.79884615 0.79884615        nan 0.79371795 0.79371795 0.79371795
#  0.78884615 0.78884615        nan 0.78884615 0.77858974 0.77858974]
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_search.py:1051: UserWarning: One or more of the test scores are non-finite: [0.         0.                nan 0.73393115 0.70064223 0.70064223
#  0.76867314 0.77581342        nan 0.73597746 0.74483995 0.74483995
#  0.77125282 0.7748787         nan 0.77273287 0.77239764 0.77239764
#  0.76822021 0.76822021        nan 0.76499214 0.76499214 0.76499214
#  0.76240626 0.76240626        nan 0.76240626 0.75586287 0.75586287]
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_search.py:1051: UserWarning: One or more of the test scores are non-finite: [0.5        0.5               nan 0.74347756 0.75858974 0.75846474
#  0.81705449 0.83005128        nan 0.7781891  0.78846795 0.78859295
#  0.8315     0.83440385        nan 0.81645513 0.81530449 0.81555769
#  0.82377244 0.82390385        nan 0.82340705 0.82340385 0.82315385
#  0.82164103 0.82176603        nan 0.82201923 0.82164103 0.82214423]
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_search.py:1051: UserWarning: One or more of the test scores are non-finite: [0.5        0.5               nan 0.66844937 0.6835443  0.6835443
#  0.72148734 0.75661392        nan 0.71617089 0.73370253 0.73370253
#  0.76148734 0.76648734        nan 0.76148734 0.7614557  0.7614557
#  0.7589557  0.7589557         nan 0.75642405 0.75642405 0.75642405
#  0.7539557  0.7539557         nan 0.7539557  0.74889241 0.74889241]
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_search.py:1051: UserWarning: One or more of the test scores are non-finite: [0.5        0.5               nan 0.66826923 0.68339744 0.68339744
#  0.72121795 0.75647436        nan 0.71602564 0.73346154 0.73346154
#  0.76147436 0.76641026        nan 0.76141026 0.76134615 0.76134615
#  0.75884615 0.75884615        nan 0.75628205 0.75628205 0.75628205
#  0.75384615 0.75384615        nan 0.75384615 0.74871795 0.74871795]
#   warnings.warn(

# %%
# Segunda rejilla de hiperparámetros
param_lr_under_cw2 = {
    "C":       [0.1, 0.5, 1, 2, 5],
    "penalty": ["l1"],
    "solver":  ["saga"]
}

# Entrenamiento Stage 2
resultado_lr_under_cw2 = ejecutar_random_search(
    modelo=lr_cw,
    parametros=param_lr_under_cw2,
    x_train=x_train_UNDER,
    y_train=y_train_UNDER,
    nombre_modelo="Logistic Regression + Under + CW (Stage 2)",
    cv=cv,
    scoring=scoring,
    metricas=metricas,
    n_iter=5
)

# Mejor modelo final
best_lr_under_cw2 = resultado_lr_under_cw2["best_model"]
# Out:
# ======================================================================
# Entrenamiento: Logistic Regression + Under + CW (Stage 2)
# ======================================================================
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
#
# Métricas medias en validación cruzada:
# mean_test_Accuracy: 0.7640
# mean_test_F1: 0.7751
# mean_test_AUROC: 0.8405
# mean_test_Recall: 0.8141
# mean_test_BalancedAccuracy: 0.7640
#
# Mejores hiperparámetros:
# solver: saga
# penalty: l1
# C: 0.5

# %%
# ── Sklearn y XGBoost ────────────────────────────────────────
modelos_finales = {
    "rf_under":  best_rf_under2,
    "xgb_under": best_xgb_under2,
    "svm_under": best_svm_under2,
    "lr_under":  best_lr_under2,
}

with open(RUTA_BASE + "modelos_finales.pkl", "wb") as f:
    pickle.dump(modelos_finales, f)

# %% [markdown]
# ## Redes neuronales

# %% [markdown]
# Generamos la función para construir el modelo

# %%
# Guardamos la dimensión de entrada (número de variables predictoras)
input_dim = x_under_df.shape[1]

# Función para construir el modelo
def build_model(hidden_layer_1, dropout_1, optimizer_name, learning_rate):

    # Definimos la arquitectura secuencial de la red
    model = keras.Sequential([

        # Capa oculta: neuronas con activación ReLU
        keras.layers.Input(shape=(input_dim,)),
        keras.layers.Dense(hidden_layer_1, activation="relu"),

        # Dropout: durante el entrenamiento apaga aleatoriamente un % de neuronas
        keras.layers.Dropout(dropout_1),

        # Capa de salida: una sola neurona con activación sigmoid
        keras.layers.Dense(1, activation="sigmoid")
    ])

    # Seleccionamos el optimizador según el parámetro recibido
    if optimizer_name == "adam":
        optimizer = keras.optimizers.Adam(learning_rate=learning_rate)
    elif optimizer_name == "sgd":
        optimizer = keras.optimizers.SGD(learning_rate=learning_rate)

    # Compilamos el modelo
    model.compile(
        optimizer=optimizer,
        loss="binary_crossentropy", #función de pérdida estándar para clasificación binaria
        metrics=["AUC"] #métrica de evaluación durante el entrenamiento
    )

    return model

#Definimos el wrapper de Scikeras
mlp = KerasClassifier(
    model=build_model,
    epochs=100,
    batch_size=32,
    verbose=0,
    callbacks=[keras.callbacks.EarlyStopping(
        monitor = "loss",
        patience=10,
        restore_best_weights=True
    )]
)

# %% [markdown]
# ### SMOTE

# %%
#Rejilla inicial de hiperparámetros
param_grid_nn_smote1 = {
    "model__hidden_layer_1": [32, 64, 128],
    "model__dropout_1":      [0.2, 0.3, 0.5],
    "model__optimizer_name": ["adam", "sgd"],
    "model__learning_rate":  [0.001, 0.01]
}

# Entrenamiento Stage 1
resultado_nn_smote1 = ejecutar_random_search(
    modelo=mlp,
    parametros=param_grid_nn_smote1,
    x_train=x_smote_df,
    y_train=y_train_smote_nn,
    nombre_modelo="NN + SMOTE (Stage 1)",
    cv=cv,
    scoring=scoring,
    metricas=metricas,
    n_iter=36
)

# Mostramos los resultados obtenidos
best_nn_smote1 = resultado_nn_smote1["best_model"]
# Out:
# ======================================================================
# Entrenamiento: NN + SMOTE (Stage 1)
# ======================================================================
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=adam; total time=  47.2s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=adam; total time=  46.4s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=adam; total time=  47.5s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=adam; total time=  48.3s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=adam; total time=  47.1s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  46.6s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  45.2s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  44.6s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  45.4s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  44.4s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=adam; total time=  48.6s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=adam; total time=  30.5s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=adam; total time=  47.4s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=adam; total time=  26.7s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=adam; total time=  46.5s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  44.1s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  44.5s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  44.0s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  43.4s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  33.7s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=adam; total time=  46.9s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=adam; total time=  49.8s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=adam; total time=  48.7s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=adam; total time=  49.6s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=adam; total time=  47.5s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  45.1s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  43.8s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  43.5s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  43.4s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  44.5s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=adam; total time=  41.1s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=adam; total time=  46.0s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=adam; total time=  47.7s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=adam; total time=  45.5s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=adam; total time=  46.7s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  44.1s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  43.9s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  46.2s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  47.3s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  29.1s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=adam; total time=  50.5s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=adam; total time=  50.9s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=adam; total time=  55.3s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=adam; total time=  53.1s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=adam; total time=  52.7s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  46.7s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  47.3s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  46.1s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  45.3s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  46.4s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=adam; total time=  47.4s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=adam; total time=  37.7s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=adam; total time=  50.2s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=adam; total time=  50.1s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=adam; total time=  37.6s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  49.4s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  46.1s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  47.7s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  48.0s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  45.6s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=adam; total time=  36.1s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=adam; total time=  48.5s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=adam; total time=  47.4s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=adam; total time=  48.2s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=adam; total time=  49.1s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  45.3s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  44.9s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  44.8s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  44.6s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  46.5s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=adam; total time=  41.0s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=adam; total time=  49.2s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=adam; total time=  36.2s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=adam; total time=  51.5s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=adam; total time=  47.7s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  44.8s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  46.9s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  39.6s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  47.6s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  46.9s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=adam; total time=  50.5s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=adam; total time=  50.1s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=adam; total time=  48.6s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=adam; total time=  49.3s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=adam; total time=  50.7s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  45.7s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  45.4s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  44.2s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  45.2s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  45.8s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=adam; total time=  37.7s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=adam; total time=  50.0s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=adam; total time=  44.3s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=adam; total time=  42.3s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=adam; total time=  48.7s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  44.7s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  44.5s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  46.4s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  45.0s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  45.3s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=adam; total time=  49.2s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=adam; total time=  49.6s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=adam; total time=  48.5s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=adam; total time=  55.3s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=adam; total time=  52.7s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  46.9s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  45.5s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  46.1s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  45.3s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  46.2s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=adam; total time=  49.0s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=adam; total time=  48.8s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=adam; total time=  50.8s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=adam; total time=  49.1s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=adam; total time=  46.7s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  34.7s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  45.0s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  45.2s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  45.0s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  34.3s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=adam; total time=  47.2s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=adam; total time=  46.5s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=adam; total time=  45.7s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=adam; total time=  48.3s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=adam; total time=  40.3s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  45.6s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  44.8s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  43.4s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  45.0s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  44.7s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=adam; total time=  33.4s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=adam; total time=  24.1s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=adam; total time=  36.3s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=adam; total time=  47.0s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=adam; total time=  39.2s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  45.8s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  45.5s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  46.5s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  33.1s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  45.1s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=adam; total time=  49.2s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=adam; total time=  46.2s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=adam; total time=  48.3s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=adam; total time=  49.5s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=adam; total time=  45.8s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  45.1s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  44.4s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  44.6s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  44.8s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  45.2s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=adam; total time=  41.7s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=adam; total time=  42.5s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=adam; total time=  39.3s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=adam; total time=  46.4s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=adam; total time=  43.2s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  44.8s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  45.0s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  47.3s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  42.6s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  30.0s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=adam; total time=  36.4s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=adam; total time=  50.2s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=adam; total time=  48.8s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=adam; total time=  47.4s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=adam; total time=  49.6s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  45.2s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  45.1s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  45.2s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  44.3s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  44.8s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=adam; total time=  54.5s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=adam; total time=  46.8s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=adam; total time=  51.3s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=adam; total time=  35.5s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=adam; total time=  31.6s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  46.7s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  40.2s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  39.4s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  35.1s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  46.1s
#
# Métricas medias en validación cruzada:
# mean_test_Accuracy: 0.9065
# mean_test_F1: 0.9109
# mean_test_AUROC: 0.9597
# mean_test_Recall: 0.9545
# mean_test_BalancedAccuracy: 0.9065
#
# Mejores hiperparámetros:
# model__optimizer_name: adam
# model__learning_rate: 0.01
# model__hidden_layer_1: 128
# model__dropout_1: 0.2

# %% [markdown]
# Ajustamos la rejilla de hiperparámetros en función de los resultados obtenidos

# %%
# Segunda rejilla de hiperparámetros
param_grid_nn_smote2 = {
    "model__optimizer_name": ["adam"],
    "model__learning_rate":  [0.005, 0.01, 0.015, 0.02],
    "model__hidden_layer_1": [96, 128, 160],
    "model__dropout_1":      [0.1, 0.2, 0.25, 0.3],
}

# Entrenamiento Stage 2
resultado_nn_smote2 = ejecutar_random_search(
    modelo=mlp,
    parametros=param_grid_nn_smote2,
    x_train=x_smote_df,
    y_train=y_train_smote_nn,
    nombre_modelo="NN + SMOTE (Stage 2)",
    cv=cv,
    scoring=scoring,
    metricas=metricas,
    n_iter=10
)

# Mejor modelo final
best_nn_smote2 = resultado_nn_smote2["best_model"]
# Out:
# ======================================================================
# Entrenamiento: NN + SMOTE (Stage 2)
# ======================================================================
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END model__dropout_1=0.1, model__hidden_layer_1=160, model__learning_rate=0.005, model__optimizer_name=adam; total time=  48.7s
# [CV] END model__dropout_1=0.1, model__hidden_layer_1=160, model__learning_rate=0.005, model__optimizer_name=adam; total time=  49.5s
# [CV] END model__dropout_1=0.1, model__hidden_layer_1=160, model__learning_rate=0.005, model__optimizer_name=adam; total time=  48.5s
# [CV] END model__dropout_1=0.1, model__hidden_layer_1=160, model__learning_rate=0.005, model__optimizer_name=adam; total time=  49.1s
# [CV] END model__dropout_1=0.1, model__hidden_layer_1=160, model__learning_rate=0.005, model__optimizer_name=adam; total time=  49.3s
# [CV] END model__dropout_1=0.1, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=adam; total time=  39.0s
# [CV] END model__dropout_1=0.1, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=adam; total time=  48.2s
# [CV] END model__dropout_1=0.1, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=adam; total time=  48.4s
# [CV] END model__dropout_1=0.1, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=adam; total time=  49.6s
# [CV] END model__dropout_1=0.1, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=adam; total time=  47.4s
# [CV] END model__dropout_1=0.25, model__hidden_layer_1=128, model__learning_rate=0.015, model__optimizer_name=adam; total time=  48.0s
# [CV] END model__dropout_1=0.25, model__hidden_layer_1=128, model__learning_rate=0.015, model__optimizer_name=adam; total time=  41.6s
# [CV] END model__dropout_1=0.25, model__hidden_layer_1=128, model__learning_rate=0.015, model__optimizer_name=adam; total time=  47.2s
# [CV] END model__dropout_1=0.25, model__hidden_layer_1=128, model__learning_rate=0.015, model__optimizer_name=adam; total time=  48.8s
# [CV] END model__dropout_1=0.25, model__hidden_layer_1=128, model__learning_rate=0.015, model__optimizer_name=adam; total time=  35.8s
# [CV] END model__dropout_1=0.25, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=adam; total time=  49.5s
# [CV] END model__dropout_1=0.25, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=adam; total time=  38.3s
# [CV] END model__dropout_1=0.25, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=adam; total time=  41.3s
# [CV] END model__dropout_1=0.25, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=adam; total time=  44.5s
# [CV] END model__dropout_1=0.25, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=adam; total time=  50.2s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.02, model__optimizer_name=adam; total time=  46.7s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.02, model__optimizer_name=adam; total time=  46.8s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.02, model__optimizer_name=adam; total time=  49.9s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.02, model__optimizer_name=adam; total time=  36.0s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.02, model__optimizer_name=adam; total time=  29.6s
# [CV] END model__dropout_1=0.1, model__hidden_layer_1=96, model__learning_rate=0.015, model__optimizer_name=adam; total time=  52.6s
# [CV] END model__dropout_1=0.1, model__hidden_layer_1=96, model__learning_rate=0.015, model__optimizer_name=adam; total time=  47.1s
# [CV] END model__dropout_1=0.1, model__hidden_layer_1=96, model__learning_rate=0.015, model__optimizer_name=adam; total time=  47.0s
# [CV] END model__dropout_1=0.1, model__hidden_layer_1=96, model__learning_rate=0.015, model__optimizer_name=adam; total time=  49.5s
# [CV] END model__dropout_1=0.1, model__hidden_layer_1=96, model__learning_rate=0.015, model__optimizer_name=adam; total time=  44.8s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.005, model__optimizer_name=adam; total time=  50.2s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.005, model__optimizer_name=adam; total time=  50.4s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.005, model__optimizer_name=adam; total time=  49.3s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.005, model__optimizer_name=adam; total time=  49.5s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.005, model__optimizer_name=adam; total time=  48.2s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=96, model__learning_rate=0.015, model__optimizer_name=adam; total time=  49.8s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=96, model__learning_rate=0.015, model__optimizer_name=adam; total time=  35.9s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=96, model__learning_rate=0.015, model__optimizer_name=adam; total time=  47.2s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=96, model__learning_rate=0.015, model__optimizer_name=adam; total time=  34.2s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=96, model__learning_rate=0.015, model__optimizer_name=adam; total time=  39.8s
# [CV] END model__dropout_1=0.25, model__hidden_layer_1=96, model__learning_rate=0.02, model__optimizer_name=adam; total time=  24.8s
# [CV] END model__dropout_1=0.25, model__hidden_layer_1=96, model__learning_rate=0.02, model__optimizer_name=adam; total time=  33.1s
# [CV] END model__dropout_1=0.25, model__hidden_layer_1=96, model__learning_rate=0.02, model__optimizer_name=adam; total time=  48.5s
# [CV] END model__dropout_1=0.25, model__hidden_layer_1=96, model__learning_rate=0.02, model__optimizer_name=adam; total time=  41.0s
# [CV] END model__dropout_1=0.25, model__hidden_layer_1=96, model__learning_rate=0.02, model__optimizer_name=adam; total time=  37.1s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=96, model__learning_rate=0.01, model__optimizer_name=adam; total time=  46.3s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=96, model__learning_rate=0.01, model__optimizer_name=adam; total time=  47.7s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=96, model__learning_rate=0.01, model__optimizer_name=adam; total time=  46.9s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=96, model__learning_rate=0.01, model__optimizer_name=adam; total time=  45.4s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=96, model__learning_rate=0.01, model__optimizer_name=adam; total time=  48.2s
#
# Métricas medias en validación cruzada:
# mean_test_Accuracy: 0.9124
# mean_test_F1: 0.9161
# mean_test_AUROC: 0.9655
# mean_test_Recall: 0.9565
# mean_test_BalancedAccuracy: 0.9124
#
# Mejores hiperparámetros:
# model__optimizer_name: adam
# model__learning_rate: 0.005
# model__hidden_layer_1: 160
# model__dropout_1: 0.1

# %% [markdown]
# ### Undersampling

# %%
# Rejilla inicial de hiperparámetros
param_grid_nn_under1 = {
    "model__hidden_layer_1": [32, 64, 128],
    "model__dropout_1":      [0.2, 0.3, 0.5],
    "model__optimizer_name": ["adam", "sgd"],
    "model__learning_rate":  [0.001, 0.01]
}

# Entrenamiento Stage 1
resultado_nn_under1 = ejecutar_random_search(
    modelo=mlp,
    parametros=param_grid_nn_under1,
    x_train=x_under_df,
    y_train=y_train_under_nn,
    nombre_modelo="NN + Undersampling (Stage 1)",
    cv=cv,
    scoring=scoring,
    metricas=metricas,
    n_iter=36
)

# Mostramos los resultados obtenidos
best_nn_under1 = resultado_nn_under1["best_model"]
# Out:
# ======================================================================
# Entrenamiento: NN + Undersampling (Stage 1)
# ======================================================================
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=adam; total time=   5.7s
# WARNING:tensorflow:5 out of the last 59 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7f28d97e14e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=adam; total time=   5.7s
# WARNING:tensorflow:5 out of the last 13 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7f28d4ed0860> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=adam; total time=   8.5s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=adam; total time=   8.5s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=adam; total time=   6.6s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=sgd; total time=   5.5s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=sgd; total time=   3.3s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=sgd; total time=   1.9s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=sgd; total time=   1.8s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=sgd; total time=   3.4s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=adam; total time=   9.2s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=adam; total time=   6.1s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=adam; total time=   6.3s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=adam; total time=   5.5s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=adam; total time=   7.8s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=sgd; total time=   7.4s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=sgd; total time=   6.7s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=sgd; total time=   2.9s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  11.0s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=sgd; total time=   5.0s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=adam; total time=   9.9s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=adam; total time=   9.8s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=adam; total time=   5.3s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=adam; total time=  10.1s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=adam; total time=   8.3s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=sgd; total time=   5.8s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=sgd; total time=   2.7s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=sgd; total time=   2.0s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=sgd; total time=   1.8s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=sgd; total time=   2.2s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=adam; total time=   8.6s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=adam; total time=   7.5s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=adam; total time=   8.6s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=adam; total time=   7.4s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=adam; total time=   6.0s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=sgd; total time=   7.2s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=sgd; total time=   7.9s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=sgd; total time=   8.9s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=sgd; total time=   7.0s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=sgd; total time=   6.8s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=adam; total time=   7.8s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=adam; total time=   7.7s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=adam; total time=   8.4s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=adam; total time=   8.0s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=adam; total time=   9.5s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=sgd; total time=   2.2s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=sgd; total time=   2.2s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=sgd; total time=   2.9s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=sgd; total time=   5.2s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=sgd; total time=   2.6s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=adam; total time=   5.5s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=adam; total time=   7.9s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=adam; total time=   6.7s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=adam; total time=   8.8s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=adam; total time=   8.0s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=sgd; total time=   8.4s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=sgd; total time=   9.1s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=sgd; total time=   7.1s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=sgd; total time=   9.0s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=sgd; total time=   7.2s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=adam; total time=   9.2s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=adam; total time=   9.5s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=adam; total time=   7.6s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=adam; total time=   8.5s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=adam; total time=   7.0s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=sgd; total time=   3.6s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=sgd; total time=   2.2s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=sgd; total time=   3.0s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=sgd; total time=   2.5s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=sgd; total time=   2.3s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=adam; total time=   5.3s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=adam; total time=   4.5s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=adam; total time=   5.5s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=adam; total time=   8.3s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=adam; total time=   7.2s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=sgd; total time=   7.5s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  10.0s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=sgd; total time=   3.2s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=sgd; total time=   5.3s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=sgd; total time=   5.8s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=adam; total time=   8.2s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=adam; total time=   7.5s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=adam; total time=   7.6s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=adam; total time=   9.2s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=adam; total time=   8.1s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=sgd; total time=   2.1s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=sgd; total time=   2.3s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=sgd; total time=   2.0s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=sgd; total time=   2.1s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=sgd; total time=   4.7s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=adam; total time=   7.6s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=adam; total time=   8.0s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=adam; total time=   6.7s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=adam; total time=   7.6s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=adam; total time=   7.5s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=sgd; total time=   5.9s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=sgd; total time=   4.9s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=sgd; total time=   8.4s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=sgd; total time=   7.0s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=sgd; total time=   9.0s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=adam; total time=   6.6s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=adam; total time=   9.4s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=adam; total time=   9.4s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=adam; total time=   8.0s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=adam; total time=   9.4s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=sgd; total time=   3.1s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=sgd; total time=   3.0s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=sgd; total time=   5.6s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=sgd; total time=   2.2s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=sgd; total time=   2.9s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=adam; total time=   5.5s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=adam; total time=   7.3s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=adam; total time=  10.1s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=adam; total time=   4.9s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=adam; total time=   7.6s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=sgd; total time=   7.7s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=sgd; total time=   9.4s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=sgd; total time=   8.2s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=sgd; total time=   3.7s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=sgd; total time=   8.0s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=adam; total time=   7.5s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=adam; total time=   5.9s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=adam; total time=   8.2s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=adam; total time=   4.0s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=adam; total time=   8.0s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=sgd; total time=   4.2s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=sgd; total time=   3.2s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=sgd; total time=   1.8s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=sgd; total time=   3.4s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=sgd; total time=   2.6s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=adam; total time=   4.0s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=adam; total time=   7.6s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=adam; total time=   5.4s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=adam; total time=   4.3s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=adam; total time=   6.2s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=sgd; total time=   2.1s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=sgd; total time=   4.6s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=sgd; total time=   8.0s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=sgd; total time=   7.5s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=sgd; total time=   9.4s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=adam; total time=   9.8s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=adam; total time=   5.1s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=adam; total time=   5.4s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=adam; total time=  12.0s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=adam; total time=   8.3s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=sgd; total time=   2.1s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=sgd; total time=   2.1s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=sgd; total time=   2.4s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=sgd; total time=   3.6s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=sgd; total time=   4.0s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=adam; total time=   6.9s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=adam; total time=   7.2s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=adam; total time=   5.5s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=adam; total time=   6.3s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=adam; total time=   5.7s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=sgd; total time=   7.9s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=sgd; total time=   4.3s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=sgd; total time=   3.8s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=sgd; total time=   6.0s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=sgd; total time=   4.1s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=adam; total time=   8.2s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=adam; total time=   6.4s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=adam; total time=   4.4s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=adam; total time=   9.0s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=adam; total time=   9.8s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=sgd; total time=   1.9s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=sgd; total time=   1.8s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=sgd; total time=   3.9s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=sgd; total time=   3.3s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=sgd; total time=   3.9s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=adam; total time=   8.1s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=adam; total time=   9.0s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=adam; total time=  10.1s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=adam; total time=   4.7s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=adam; total time=   9.4s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=sgd; total time=   7.7s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=sgd; total time=   6.7s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=sgd; total time=   4.7s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=sgd; total time=   8.4s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=sgd; total time=   5.6s
#
# Métricas medias en validación cruzada:
# mean_test_Accuracy: 0.7439
# mean_test_F1: 0.7505
# mean_test_AUROC: 0.8105
# mean_test_Recall: 0.7687
# mean_test_BalancedAccuracy: 0.7438
#
# Mejores hiperparámetros:
# model__optimizer_name: adam
# model__learning_rate: 0.001
# model__hidden_layer_1: 128
# model__dropout_1: 0.3

# %% [markdown]
# Ajustamos la rejilla de hiperparámetros en función de los resultados obtenidos

# %%
# Segunda rejilla de hiperparámetros
param_grid_nn_under2 = {
    "model__optimizer_name": ["adam"],
    "model__learning_rate":  [0.005, 0.01, 0.015, 0.02],
    "model__hidden_layer_1": [16, 32, 48, 64],
    "model__dropout_1":      [0.4, 0.5, 0.55, 0.6],
}

# Entrenamiento Stage 2
resultado_nn_under2 = ejecutar_random_search(
    modelo=mlp,
    parametros=param_grid_nn_under2,
    x_train=x_under_df,
    y_train=y_train_under_nn,
    nombre_modelo="NN + Undersampling (Stage 2)",
    cv=cv,
    scoring=scoring,
    metricas=metricas,
    n_iter=10
)

# Mejor modelo final
best_nn_under2 = resultado_nn_under2["best_model"]
# Out:
# ======================================================================
# Entrenamiento: NN + Undersampling (Stage 2)
# ======================================================================
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END model__dropout_1=0.55, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=adam; total time=   5.9s
# [CV] END model__dropout_1=0.55, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=adam; total time=   4.9s
# [CV] END model__dropout_1=0.55, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=adam; total time=   6.3s
# [CV] END model__dropout_1=0.55, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=adam; total time=   4.4s
# [CV] END model__dropout_1=0.55, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=adam; total time=   6.5s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=16, model__learning_rate=0.02, model__optimizer_name=adam; total time=   5.6s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=16, model__learning_rate=0.02, model__optimizer_name=adam; total time=   4.4s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=16, model__learning_rate=0.02, model__optimizer_name=adam; total time=   7.0s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=16, model__learning_rate=0.02, model__optimizer_name=adam; total time=   4.5s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=16, model__learning_rate=0.02, model__optimizer_name=adam; total time=   3.8s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=16, model__learning_rate=0.005, model__optimizer_name=adam; total time=   6.6s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=16, model__learning_rate=0.005, model__optimizer_name=adam; total time=   5.4s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=16, model__learning_rate=0.005, model__optimizer_name=adam; total time=   5.9s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=16, model__learning_rate=0.005, model__optimizer_name=adam; total time=   6.2s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=16, model__learning_rate=0.005, model__optimizer_name=adam; total time=   6.6s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.015, model__optimizer_name=adam; total time=   8.7s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.015, model__optimizer_name=adam; total time=   7.9s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.015, model__optimizer_name=adam; total time=   6.5s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.015, model__optimizer_name=adam; total time=   7.5s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.015, model__optimizer_name=adam; total time=   5.5s
# [CV] END model__dropout_1=0.4, model__hidden_layer_1=16, model__learning_rate=0.015, model__optimizer_name=adam; total time=   5.2s
# [CV] END model__dropout_1=0.4, model__hidden_layer_1=16, model__learning_rate=0.015, model__optimizer_name=adam; total time=   5.1s
# [CV] END model__dropout_1=0.4, model__hidden_layer_1=16, model__learning_rate=0.015, model__optimizer_name=adam; total time=   5.5s
# [CV] END model__dropout_1=0.4, model__hidden_layer_1=16, model__learning_rate=0.015, model__optimizer_name=adam; total time=   7.0s
# [CV] END model__dropout_1=0.4, model__hidden_layer_1=16, model__learning_rate=0.015, model__optimizer_name=adam; total time=   5.9s
# [CV] END model__dropout_1=0.55, model__hidden_layer_1=32, model__learning_rate=0.015, model__optimizer_name=adam; total time=   4.1s
# [CV] END model__dropout_1=0.55, model__hidden_layer_1=32, model__learning_rate=0.015, model__optimizer_name=adam; total time=   4.4s
# [CV] END model__dropout_1=0.55, model__hidden_layer_1=32, model__learning_rate=0.015, model__optimizer_name=adam; total time=   4.3s
# [CV] END model__dropout_1=0.55, model__hidden_layer_1=32, model__learning_rate=0.015, model__optimizer_name=adam; total time=   2.8s
# [CV] END model__dropout_1=0.55, model__hidden_layer_1=32, model__learning_rate=0.015, model__optimizer_name=adam; total time=   5.4s
# [CV] END model__dropout_1=0.6, model__hidden_layer_1=16, model__learning_rate=0.015, model__optimizer_name=adam; total time=   4.0s
# [CV] END model__dropout_1=0.6, model__hidden_layer_1=16, model__learning_rate=0.015, model__optimizer_name=adam; total time=   5.4s
# [CV] END model__dropout_1=0.6, model__hidden_layer_1=16, model__learning_rate=0.015, model__optimizer_name=adam; total time=   5.3s
# [CV] END model__dropout_1=0.6, model__hidden_layer_1=16, model__learning_rate=0.015, model__optimizer_name=adam; total time=   4.0s
# [CV] END model__dropout_1=0.6, model__hidden_layer_1=16, model__learning_rate=0.015, model__optimizer_name=adam; total time=   6.3s
# [CV] END model__dropout_1=0.55, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=adam; total time=  15.9s
# [CV] END model__dropout_1=0.55, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=adam; total time=   4.5s
# [CV] END model__dropout_1=0.55, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=adam; total time=   4.4s
# [CV] END model__dropout_1=0.55, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=adam; total time=   3.9s
# [CV] END model__dropout_1=0.55, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=adam; total time=   7.2s
# [CV] END model__dropout_1=0.6, model__hidden_layer_1=64, model__learning_rate=0.005, model__optimizer_name=adam; total time=   5.0s
# [CV] END model__dropout_1=0.6, model__hidden_layer_1=64, model__learning_rate=0.005, model__optimizer_name=adam; total time=  10.1s
# [CV] END model__dropout_1=0.6, model__hidden_layer_1=64, model__learning_rate=0.005, model__optimizer_name=adam; total time=   5.3s
# [CV] END model__dropout_1=0.6, model__hidden_layer_1=64, model__learning_rate=0.005, model__optimizer_name=adam; total time=   5.4s
# [CV] END model__dropout_1=0.6, model__hidden_layer_1=64, model__learning_rate=0.005, model__optimizer_name=adam; total time=   3.9s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=48, model__learning_rate=0.02, model__optimizer_name=adam; total time=  10.5s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=48, model__learning_rate=0.02, model__optimizer_name=adam; total time=   3.9s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=48, model__learning_rate=0.02, model__optimizer_name=adam; total time=  10.0s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=48, model__learning_rate=0.02, model__optimizer_name=adam; total time=   5.9s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=48, model__learning_rate=0.02, model__optimizer_name=adam; total time=   8.2s
#
# Métricas medias en validación cruzada:
# mean_test_Accuracy: 0.7212
# mean_test_F1: 0.7403
# mean_test_AUROC: 0.8019
# mean_test_Recall: 0.7935
# mean_test_BalancedAccuracy: 0.7208
#
# Mejores hiperparámetros:
# model__optimizer_name: adam
# model__learning_rate: 0.015
# model__hidden_layer_1: 32
# model__dropout_1: 0.55

# %% [markdown]
# ### Class_weight

# %%
# Rejilla inicial de hiperparámetros
param_grid_nn_cw1 = {
    "model__hidden_layer_1": [32, 64, 128],
    "model__dropout_1":      [0.2, 0.3, 0.5],
    "model__optimizer_name": ["adam", "sgd"],
    "model__learning_rate":  [0.001, 0.01]
}

# Entrenamiento Stage 1
resultado_nn_cw1 = ejecutar_random_search(
    modelo=mlp,
    parametros=param_grid_nn_cw1,
    x_train=x_desbal_df,
    y_train=y_train_desbal_nn,
    nombre_modelo="NN + Class Weight (Stage 1)",
    cv=cv,
    scoring=scoring,
    metricas=metricas,
    n_iter=36,
    fit_params={
        "class_weight": {0: 1, 1: scale}
    }
)

# Mostramos los resultados obtenidos
best_nn_cw1 = resultado_nn_cw1["best_model"]
# Out:
# ======================================================================
# Entrenamiento: NN + Class Weight (Stage 1)
# ======================================================================
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=adam; total time=  27.7s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=adam; total time=  17.8s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=adam; total time=  30.6s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=adam; total time=  22.9s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=adam; total time=  14.3s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  23.5s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  27.8s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  21.4s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  27.9s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  28.0s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=adam; total time=  29.1s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=adam; total time=  21.4s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=adam; total time=  26.9s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=adam; total time=  17.5s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=adam; total time=  20.8s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  21.8s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  24.0s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  16.4s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  27.9s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  17.2s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=adam; total time=  30.8s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=adam; total time=  30.1s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=adam; total time=  30.0s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=adam; total time=  17.0s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=adam; total time=  29.5s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  28.2s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  27.6s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  27.5s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  27.5s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  28.1s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=adam; total time=  16.4s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=adam; total time=  17.2s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=adam; total time=  18.3s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=adam; total time=  11.7s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=adam; total time=  15.6s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  20.7s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  19.4s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  14.3s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  15.6s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  15.6s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=adam; total time=  29.5s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=adam; total time=  29.6s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=adam; total time=  29.5s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=adam; total time=  24.8s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=adam; total time=  29.3s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  28.3s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  27.9s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  28.5s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  28.2s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  29.1s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=adam; total time=  16.1s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=adam; total time=  21.5s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=adam; total time=  23.9s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=adam; total time=  19.1s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=adam; total time=  23.3s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  15.4s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  13.4s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  15.4s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  15.9s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  12.9s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=adam; total time=  24.5s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=adam; total time=  29.7s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=adam; total time=  17.9s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=adam; total time=  19.9s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=adam; total time=  21.0s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  19.2s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  27.5s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  23.3s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  27.8s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  27.8s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=adam; total time=  19.1s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=adam; total time=  25.1s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=adam; total time=  18.7s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=adam; total time=  28.1s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=adam; total time=  28.1s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  20.7s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  19.7s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  16.5s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  18.1s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  17.5s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=adam; total time=  16.7s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=adam; total time=  31.5s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=adam; total time=  23.2s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=adam; total time=  22.7s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=adam; total time=  21.1s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  28.7s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  29.6s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  28.0s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  28.0s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  28.0s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=adam; total time=  21.0s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=adam; total time=  26.2s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=adam; total time=  21.6s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=adam; total time=  23.3s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=adam; total time=  25.7s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  18.8s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  21.6s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  17.5s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  16.5s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  15.4s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=adam; total time=  24.8s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=adam; total time=  19.2s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=adam; total time=  25.1s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=adam; total time=  29.6s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=adam; total time=  24.2s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  28.7s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  26.1s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  28.0s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  28.8s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  28.9s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=adam; total time=  19.4s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=adam; total time=  22.5s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=adam; total time=  18.4s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=adam; total time=  22.1s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=adam; total time=  22.5s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  15.3s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  13.5s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  18.4s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  17.5s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  14.1s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=adam; total time=  17.9s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=adam; total time=  17.7s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=adam; total time=  21.7s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=adam; total time=  14.5s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=adam; total time=  22.0s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  15.1s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  24.8s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  15.7s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  15.9s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  22.5s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=adam; total time=  16.3s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=adam; total time=  17.0s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=adam; total time=  11.5s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=adam; total time=  14.6s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=adam; total time=  15.4s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  26.5s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  22.8s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  16.6s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  11.3s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=32, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  18.5s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=adam; total time=  24.1s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=adam; total time=  17.7s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=adam; total time=  23.1s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=adam; total time=  26.1s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=adam; total time=  19.9s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  27.6s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  27.8s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  12.2s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  24.0s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  27.8s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=adam; total time=  10.4s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=adam; total time=  19.4s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=adam; total time=  24.7s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=adam; total time=   9.4s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=adam; total time=  13.5s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  16.9s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  22.4s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  14.0s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=sgd; total time=   8.1s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  13.8s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=adam; total time=  26.0s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=adam; total time=  24.1s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=adam; total time=  18.9s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=adam; total time=  22.8s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=adam; total time=  22.2s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  18.8s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  19.7s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  13.0s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  28.5s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=sgd; total time=  28.5s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=adam; total time=  19.8s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=adam; total time=  15.8s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=adam; total time=  23.1s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=adam; total time=  15.7s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=adam; total time=  21.0s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  17.2s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  17.3s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  23.1s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  28.8s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  26.8s
#
# Métricas medias en validación cruzada:
# mean_test_Accuracy: 0.7380
# mean_test_F1: 0.2275
# mean_test_AUROC: 0.8445
# mean_test_Recall: 0.7892
# mean_test_BalancedAccuracy: 0.7623
#
# Mejores hiperparámetros:
# model__optimizer_name: sgd
# model__learning_rate: 0.01
# model__hidden_layer_1: 128
# model__dropout_1: 0.2

# %% [markdown]
# Ajustamos la rejilla de hiperparámetros en función de los resultados obtenidos

# %%
# Segunda rejilla de hiperparámetros
param_grid_nn_cw2 = {
    "model__optimizer_name": ["sgd"],
    "model__learning_rate":  [0.005, 0.01, 0.015, 0.02],
    "model__hidden_layer_1": [48, 64, 80, 96],
    "model__dropout_1":      [0.1, 0.2, 0.3],
}

# Entrenamiento Stage 2
resultado_nn_cw2 = ejecutar_random_search(
    modelo=mlp,
    parametros=param_grid_nn_cw2,
    x_train=x_desbal_df,
    y_train=y_train_desbal_nn,
    nombre_modelo="NN + Class Weight (Stage 2)",
    cv=cv,
    scoring=scoring,
    metricas=metricas,
    n_iter=10,
    fit_params={
        "class_weight": {0: 1, 1: scale}
    }
)

# Mejor modelo final
best_nn_cw2 = resultado_nn_cw2["best_model"]
# Out:
# ======================================================================
# Entrenamiento: NN + Class Weight (Stage 2)
# ======================================================================
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END model__dropout_1=0.1, model__hidden_layer_1=80, model__learning_rate=0.005, model__optimizer_name=sgd; total time=  27.3s
# [CV] END model__dropout_1=0.1, model__hidden_layer_1=80, model__learning_rate=0.005, model__optimizer_name=sgd; total time=  22.5s
# [CV] END model__dropout_1=0.1, model__hidden_layer_1=80, model__learning_rate=0.005, model__optimizer_name=sgd; total time=  24.2s
# [CV] END model__dropout_1=0.1, model__hidden_layer_1=80, model__learning_rate=0.005, model__optimizer_name=sgd; total time=  26.8s
# [CV] END model__dropout_1=0.1, model__hidden_layer_1=80, model__learning_rate=0.005, model__optimizer_name=sgd; total time=  29.6s
# [CV] END model__dropout_1=0.1, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  14.4s
# [CV] END model__dropout_1=0.1, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  29.3s
# [CV] END model__dropout_1=0.1, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  22.4s
# [CV] END model__dropout_1=0.1, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  16.8s
# [CV] END model__dropout_1=0.1, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  17.5s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=96, model__learning_rate=0.015, model__optimizer_name=sgd; total time=  13.1s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=96, model__learning_rate=0.015, model__optimizer_name=sgd; total time=  12.8s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=96, model__learning_rate=0.015, model__optimizer_name=sgd; total time=  18.2s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=96, model__learning_rate=0.015, model__optimizer_name=sgd; total time=  18.3s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=96, model__learning_rate=0.015, model__optimizer_name=sgd; total time=  26.3s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=96, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  21.2s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=96, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  26.3s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=96, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  19.7s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=96, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  18.0s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=96, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  16.0s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=48, model__learning_rate=0.02, model__optimizer_name=sgd; total time=  14.4s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=48, model__learning_rate=0.02, model__optimizer_name=sgd; total time=  19.8s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=48, model__learning_rate=0.02, model__optimizer_name=sgd; total time=  12.3s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=48, model__learning_rate=0.02, model__optimizer_name=sgd; total time=  13.8s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=48, model__learning_rate=0.02, model__optimizer_name=sgd; total time=  19.8s
# [CV] END model__dropout_1=0.1, model__hidden_layer_1=48, model__learning_rate=0.015, model__optimizer_name=sgd; total time=  16.6s
# [CV] END model__dropout_1=0.1, model__hidden_layer_1=48, model__learning_rate=0.015, model__optimizer_name=sgd; total time=  12.0s
# [CV] END model__dropout_1=0.1, model__hidden_layer_1=48, model__learning_rate=0.015, model__optimizer_name=sgd; total time=  14.8s
# [CV] END model__dropout_1=0.1, model__hidden_layer_1=48, model__learning_rate=0.015, model__optimizer_name=sgd; total time=  16.9s
# [CV] END model__dropout_1=0.1, model__hidden_layer_1=48, model__learning_rate=0.015, model__optimizer_name=sgd; total time=  26.9s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=48, model__learning_rate=0.005, model__optimizer_name=sgd; total time=  23.0s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=48, model__learning_rate=0.005, model__optimizer_name=sgd; total time=  28.7s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=48, model__learning_rate=0.005, model__optimizer_name=sgd; total time=  16.5s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=48, model__learning_rate=0.005, model__optimizer_name=sgd; total time=  16.3s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=48, model__learning_rate=0.005, model__optimizer_name=sgd; total time=  21.4s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=64, model__learning_rate=0.015, model__optimizer_name=sgd; total time=  17.1s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=64, model__learning_rate=0.015, model__optimizer_name=sgd; total time=  17.2s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=64, model__learning_rate=0.015, model__optimizer_name=sgd; total time=  21.9s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=64, model__learning_rate=0.015, model__optimizer_name=sgd; total time=  16.0s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=64, model__learning_rate=0.015, model__optimizer_name=sgd; total time=  11.5s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=80, model__learning_rate=0.02, model__optimizer_name=sgd; total time=  17.0s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=80, model__learning_rate=0.02, model__optimizer_name=sgd; total time=  28.5s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=80, model__learning_rate=0.02, model__optimizer_name=sgd; total time=  21.2s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=80, model__learning_rate=0.02, model__optimizer_name=sgd; total time=   9.7s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=80, model__learning_rate=0.02, model__optimizer_name=sgd; total time=  11.6s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  26.2s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  12.9s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  11.0s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  16.9s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=sgd; total time=  20.6s
#
# Métricas medias en validación cruzada:
# mean_test_Accuracy: 0.7546
# mean_test_F1: 0.2500
# mean_test_AUROC: 0.8464
# mean_test_Recall: 0.8240
# mean_test_BalancedAccuracy: 0.7875
#
# Mejores hiperparámetros:
# model__optimizer_name: sgd
# model__learning_rate: 0.01
# model__hidden_layer_1: 64
# model__dropout_1: 0.1

# %% [markdown]
# ### Undersampling + class_weight

# %%
# Rejilla inicial de hiperparámetros
param_grid_nn_under_cw1 = {
    "model__hidden_layer_1": [32, 64, 128],
    "model__dropout_1":      [0.2, 0.3, 0.5],
    "model__optimizer_name": ["adam", "sgd"],
    "model__learning_rate":  [0.001, 0.01]
}

# Entrenamiento Stage 1
resultado_nn_under_cw1 = ejecutar_random_search(
    modelo=mlp,
    parametros=param_grid_nn_under_cw1,
    x_train=x_under_df,
    y_train=y_train_under_nn,
    nombre_modelo="NN + Under + Class Weight (Stage 1)",
    cv=cv,
    scoring=scoring,
    metricas=metricas,
    n_iter=10,
    fit_params={
        "class_weight": {0: 1, 1: scale}
    }
)

# Mostramos los resultados obtenidos
best_nn_under_cw1 = resultado_nn_under_cw1["best_model"]
# Out:
# ======================================================================
# Entrenamiento: NN + Under + Class Weight (Stage 1)
# ======================================================================
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=adam; total time=   9.9s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=adam; total time=   7.1s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=adam; total time=   6.7s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=adam; total time=   8.2s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=adam; total time=   8.1s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=sgd; total time=   5.4s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=sgd; total time=   5.3s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=sgd; total time=   4.7s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=sgd; total time=   6.9s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=sgd; total time=   4.7s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=sgd; total time=   4.1s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=sgd; total time=   6.7s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=sgd; total time=   4.6s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=sgd; total time=   5.2s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=sgd; total time=   5.7s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=adam; total time=  10.0s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=adam; total time=   5.8s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=adam; total time=   9.6s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=adam; total time=   5.3s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=128, model__learning_rate=0.01, model__optimizer_name=adam; total time=   6.2s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=sgd; total time=   5.6s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=sgd; total time=   5.0s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=sgd; total time=   6.6s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=sgd; total time=   4.1s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=sgd; total time=   4.9s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=adam; total time=   9.3s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=adam; total time=   9.9s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=adam; total time=   8.0s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=adam; total time=   9.6s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=128, model__learning_rate=0.001, model__optimizer_name=adam; total time=   9.9s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=adam; total time=   7.6s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=adam; total time=   8.9s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=adam; total time=   9.2s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=adam; total time=   8.0s
# [CV] END model__dropout_1=0.2, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=adam; total time=   7.5s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=sgd; total time=   3.6s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=sgd; total time=   3.9s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=sgd; total time=   5.7s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=sgd; total time=   5.0s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=sgd; total time=   4.2s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=adam; total time=   5.8s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=adam; total time=   4.1s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=adam; total time=   3.6s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=adam; total time=   7.5s
# [CV] END model__dropout_1=0.3, model__hidden_layer_1=32, model__learning_rate=0.001, model__optimizer_name=adam; total time=   3.9s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=sgd; total time=   6.1s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=sgd; total time=   4.8s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=sgd; total time=   4.1s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=sgd; total time=   4.9s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.001, model__optimizer_name=sgd; total time=   4.9s
#
# Métricas medias en validación cruzada:
# mean_test_Accuracy: 0.5778
# mean_test_F1: 0.7001
# mean_test_AUROC: 0.7871
# mean_test_Recall: 0.9850
# mean_test_BalancedAccuracy: 0.5778
#
# Mejores hiperparámetros:
# model__optimizer_name: adam
# model__learning_rate: 0.001
# model__hidden_layer_1: 128
# model__dropout_1: 0.2

# %% [markdown]
# Ajustamos la rejilla de hiperparámetros en función de los resultados obtenidos

# %%
# Segunda rejilla de hiperparámetros
param_grid_nn_under_cw2 = {
    "model__optimizer_name": ["adam"],
    "model__learning_rate":  [0.007, 0.01, 0.012],
    "model__hidden_layer_1": [56, 64, 72, 80],
    "model__dropout_1":      [0.4, 0.45, 0.5, 0.55],
}

# Entrenamiento Stage 2
resultado_nn_under_cw2 = ejecutar_random_search(
    modelo=mlp,
    parametros=param_grid_nn_under_cw2,
    x_train=x_under_df,
    y_train=y_train_under_nn,
    nombre_modelo="NN + Under + Class Weight (Stage 2)",
    cv=cv,
    scoring=scoring,
    metricas=metricas,
    n_iter=10,
    fit_params={
        "class_weight": {0: 1, 1: scale}
    }
)

# Mejor modelo final
best_nn_under_cw2 = resultado_nn_under_cw2["best_model"]
# Out:
# ======================================================================
# Entrenamiento: NN + Under + Class Weight (Stage 2)
# ======================================================================
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END model__dropout_1=0.4, model__hidden_layer_1=72, model__learning_rate=0.012, model__optimizer_name=adam; total time=   8.9s
# [CV] END model__dropout_1=0.4, model__hidden_layer_1=72, model__learning_rate=0.012, model__optimizer_name=adam; total time=   7.8s
# [CV] END model__dropout_1=0.4, model__hidden_layer_1=72, model__learning_rate=0.012, model__optimizer_name=adam; total time=   8.3s
# [CV] END model__dropout_1=0.4, model__hidden_layer_1=72, model__learning_rate=0.012, model__optimizer_name=adam; total time=   8.5s
# [CV] END model__dropout_1=0.4, model__hidden_layer_1=72, model__learning_rate=0.012, model__optimizer_name=adam; total time=   6.2s
# [CV] END model__dropout_1=0.4, model__hidden_layer_1=64, model__learning_rate=0.012, model__optimizer_name=adam; total time=   6.9s
# [CV] END model__dropout_1=0.4, model__hidden_layer_1=64, model__learning_rate=0.012, model__optimizer_name=adam; total time=   5.7s
# [CV] END model__dropout_1=0.4, model__hidden_layer_1=64, model__learning_rate=0.012, model__optimizer_name=adam; total time=   7.1s
# [CV] END model__dropout_1=0.4, model__hidden_layer_1=64, model__learning_rate=0.012, model__optimizer_name=adam; total time=   7.5s
# [CV] END model__dropout_1=0.4, model__hidden_layer_1=64, model__learning_rate=0.012, model__optimizer_name=adam; total time=   9.3s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=72, model__learning_rate=0.007, model__optimizer_name=adam; total time=   9.3s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=72, model__learning_rate=0.007, model__optimizer_name=adam; total time=   7.0s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=72, model__learning_rate=0.007, model__optimizer_name=adam; total time=   7.2s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=72, model__learning_rate=0.007, model__optimizer_name=adam; total time=   5.5s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=72, model__learning_rate=0.007, model__optimizer_name=adam; total time=   8.3s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.012, model__optimizer_name=adam; total time=   4.7s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.012, model__optimizer_name=adam; total time=   8.1s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.012, model__optimizer_name=adam; total time=   5.1s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.012, model__optimizer_name=adam; total time=   6.2s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.012, model__optimizer_name=adam; total time=   7.8s
# [CV] END model__dropout_1=0.45, model__hidden_layer_1=72, model__learning_rate=0.01, model__optimizer_name=adam; total time=   8.3s
# [CV] END model__dropout_1=0.45, model__hidden_layer_1=72, model__learning_rate=0.01, model__optimizer_name=adam; total time=   5.7s
# [CV] END model__dropout_1=0.45, model__hidden_layer_1=72, model__learning_rate=0.01, model__optimizer_name=adam; total time=   6.1s
# [CV] END model__dropout_1=0.45, model__hidden_layer_1=72, model__learning_rate=0.01, model__optimizer_name=adam; total time=   6.8s
# [CV] END model__dropout_1=0.45, model__hidden_layer_1=72, model__learning_rate=0.01, model__optimizer_name=adam; total time=   5.1s
# [CV] END model__dropout_1=0.4, model__hidden_layer_1=56, model__learning_rate=0.012, model__optimizer_name=adam; total time=   7.9s
# [CV] END model__dropout_1=0.4, model__hidden_layer_1=56, model__learning_rate=0.012, model__optimizer_name=adam; total time=   7.9s
# [CV] END model__dropout_1=0.4, model__hidden_layer_1=56, model__learning_rate=0.012, model__optimizer_name=adam; total time=   9.7s
# [CV] END model__dropout_1=0.4, model__hidden_layer_1=56, model__learning_rate=0.012, model__optimizer_name=adam; total time=   7.5s
# [CV] END model__dropout_1=0.4, model__hidden_layer_1=56, model__learning_rate=0.012, model__optimizer_name=adam; total time=   6.5s
# [CV] END model__dropout_1=0.45, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=adam; total time=  19.3s
# [CV] END model__dropout_1=0.45, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=adam; total time=   8.5s
# [CV] END model__dropout_1=0.45, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=adam; total time=  10.4s
# [CV] END model__dropout_1=0.45, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=adam; total time=   9.1s
# [CV] END model__dropout_1=0.45, model__hidden_layer_1=64, model__learning_rate=0.01, model__optimizer_name=adam; total time=   7.4s
# [CV] END model__dropout_1=0.55, model__hidden_layer_1=56, model__learning_rate=0.012, model__optimizer_name=adam; total time=   6.6s
# [CV] END model__dropout_1=0.55, model__hidden_layer_1=56, model__learning_rate=0.012, model__optimizer_name=adam; total time=   6.2s
# [CV] END model__dropout_1=0.55, model__hidden_layer_1=56, model__learning_rate=0.012, model__optimizer_name=adam; total time=   4.9s
# [CV] END model__dropout_1=0.55, model__hidden_layer_1=56, model__learning_rate=0.012, model__optimizer_name=adam; total time=   8.8s
# [CV] END model__dropout_1=0.55, model__hidden_layer_1=56, model__learning_rate=0.012, model__optimizer_name=adam; total time=   5.5s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.007, model__optimizer_name=adam; total time=   7.2s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.007, model__optimizer_name=adam; total time=   6.4s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.007, model__optimizer_name=adam; total time=   6.8s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.007, model__optimizer_name=adam; total time=   5.7s
# [CV] END model__dropout_1=0.5, model__hidden_layer_1=64, model__learning_rate=0.007, model__optimizer_name=adam; total time=   9.5s
# [CV] END model__dropout_1=0.55, model__hidden_layer_1=56, model__learning_rate=0.01, model__optimizer_name=adam; total time=   4.8s
# [CV] END model__dropout_1=0.55, model__hidden_layer_1=56, model__learning_rate=0.01, model__optimizer_name=adam; total time=   7.1s
# [CV] END model__dropout_1=0.55, model__hidden_layer_1=56, model__learning_rate=0.01, model__optimizer_name=adam; total time=   7.8s
# [CV] END model__dropout_1=0.55, model__hidden_layer_1=56, model__learning_rate=0.01, model__optimizer_name=adam; total time=   6.6s
# [CV] END model__dropout_1=0.55, model__hidden_layer_1=56, model__learning_rate=0.01, model__optimizer_name=adam; total time=   8.8s
#
# Métricas medias en validación cruzada:
# mean_test_Accuracy: 0.5854
# mean_test_F1: 0.7016
# mean_test_AUROC: 0.8078
# mean_test_Recall: 0.9750
# mean_test_BalancedAccuracy: 0.5855
#
# Mejores hiperparámetros:
# model__optimizer_name: adam
# model__learning_rate: 0.01
# model__hidden_layer_1: 56
# model__dropout_1: 0.55

# %% [markdown]
# #

# %% [markdown]
# # Validación de modelos

# %% [markdown]
# Creamos una función de validación y visualización

# %%
# Función de validación y visualización en test
def evaluar_modelo(
    modelo,
    x_test,
    y_test,
    nombre_modelo,
    umbral=0.5,
    es_nn=False
):

    # ── Predicciones ─────────────────────────────────────
    if es_nn:
        y_prob = modelo.predict_proba(x_test)[:, 1]
        y_pred = (y_prob >= umbral).astype(int)
    else:
        y_pred = modelo.predict(x_test)
        y_prob = modelo.predict_proba(x_test)[:, 1]

    # ── Métricas ─────────────────────────────────────────
    metricas = pd.DataFrame({
        "Test": [
            accuracy_score(y_test, y_pred),
            f1_score(y_test, y_pred, pos_label=1),
            roc_auc_score(y_test, y_prob),
            recall_score(y_test, y_pred, pos_label=1),
            balanced_accuracy_score(y_test, y_pred),
            average_precision_score(y_test, y_prob)
        ]
    }, index=[
        "Accuracy",
        "F1",
        "AUROC",
        "Recall",
        "Balanced Accuracy",
        "Average Precision"
    ])

    print(metricas.round(4))

    # ── Gráficos ─────────────────────────────────────────
    fig, axes = plt.subplots(1, 2, figsize=(14, 5))

    # ROC
    fpr, tpr, _ = roc_curve(y_test, y_prob)
    auroc = auc(fpr, tpr)

    axes[0].plot(
        fpr,
        tpr,
        lw=2,
        label=f'AUROC = {auroc:.4f}'
    )

    axes[0].plot([0, 1], [0, 1], linestyle='--', lw=1)

    axes[0].set_xlabel('Tasa de Falsos Positivos')
    axes[0].set_ylabel('Tasa de Verdaderos Positivos')
    axes[0].set_title(f'Curva ROC — {nombre_modelo}')
    axes[0].legend(loc='lower right')

    # Matriz de confusión
    cm = confusion_matrix(y_test, y_pred, labels=[0, 1])

    ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=["No", "Sí"]
    ).plot(ax=axes[1], colorbar=False, cmap="Blues")

    axes[1].set_title(f'Matriz de Confusión — {nombre_modelo}')

    plt.tight_layout()
    plt.show()

    return metricas

# %% [markdown]
# ## Random Forest

# %% [markdown]
# ### SMOTE

# %%
## Validación RF + SMOTE
metricas_rf_smote = evaluar_modelo(
    best_rf_smote2,
    x_test_final,
    y_test_final,
    "RF SMOTE"
)
# Out:
#                      Test
# Accuracy           0.8973
# F1                 0.1322
# AUROC              0.7769
# Recall             0.1600
# Balanced Accuracy  0.5476
# Average Precision  0.1154

# %% [markdown]
# ### Undersampling

# %%
## Validación RF + Undersampling
metricas_rf_under = evaluar_modelo(
    best_rf_under2,
    x_test_final,
    y_test_final,
    "RF Undersampling"
)
# Out:
#                      Test
# Accuracy           0.7260
# F1                 0.2045
# AUROC              0.8037
# Recall             0.7200
# Balanced Accuracy  0.7232
# Average Precision  0.1532

# %% [markdown]
# ### Class - weights

# %%
# Validación RF + Class weights
metricas_rf_cw = evaluar_modelo(
    best_rf_cw2,
    x_test_final,
    y_test_final,
    "RF Class Weight"
)
# Out:
#                      Test
# Accuracy           0.9051
# F1                 0.1983
# AUROC              0.8029
# Recall             0.2400
# Balanced Accuracy  0.5897
# Average Precision  0.1428

# %% [markdown]
# ### Undersampling + class - weights

# %%
## Validación RF + Undersampling + Class weights
metricas_rf_under_cw = evaluar_modelo(
    best_rf_under_cw2,
    x_test_final,
    y_test_final,
    "RF Under + Class Weight"
)
# Out:
#                      Test
# Accuracy           0.7172
# F1                 0.1950
# AUROC              0.7999
# Recall             0.7000
# Balanced Accuracy  0.7091
# Average Precision  0.1477

# %% [markdown]
# ## XGBoost

# %% [markdown]
# ###SMOTE

# %%
## Validación XGBoost + SMOTE
metricas_xgb_smote = evaluar_modelo(
    best_xgb_smote2,
    x_test_final,
    y_test_final,
    "XGBoost SMOTE"
)
# Out:
#                      Test
# Accuracy           0.9041
# F1                 0.1404
# AUROC              0.7534
# Recall             0.1600
# Balanced Accuracy  0.5512
# Average Precision  0.1116

# %% [markdown]
# ### Undersampling

# %%
## Validación XGBoost + Undersampling
metricas_xgb_under = evaluar_modelo(
    best_xgb_under2,
    x_test_final,
    y_test_final,
    "XGBoost Undersampling"
)
# Out:
#                      Test
# Accuracy           0.7221
# F1                 0.1977
# AUROC              0.8091
# Recall             0.7000
# Balanced Accuracy  0.7116
# Average Precision  0.1607

# %% [markdown]
# ### scale_pos_weight

# %%
## Validación XGBoost + scale_pos_weight
metricas_xgb_cw = evaluar_modelo(
    best_xgb_cw2,
    x_test_final,
    y_test_final,
    "XGBoost scale_pos_weight"
)
# Out:
#                      Test
# Accuracy           0.7192
# F1                 0.2050
# AUROC              0.8151
# Recall             0.7400
# Balanced Accuracy  0.7291
# Average Precision  0.1699

# %% [markdown]
# ### Undersampling + scale_pos_weight

# %%
## Validación XGBoost + Undersampling + scale_pos_weight
metricas_xgb_under_cw = evaluar_modelo(
    best_xgb_under_cw2,
    x_test_final,
    y_test_final,
    "XGBoost Under + scale_pos_weight"
)
# Out:
#                      Test
# Accuracy           0.4031
# F1                 0.1360
# AUROC              0.8087
# Recall             0.9600
# Balanced Accuracy  0.6672
# Average Precision  0.1606

# %% [markdown]
# ## SVM

# %% [markdown]
# ### SMOTE

# %%
# Validación SVM + SMOTE
metricas_svm_smote = evaluar_modelo(
    best_svm_smote2,
    x_test_final,
    y_test_final,
    "SVM SMOTE"
)
# Out:
#                      Test
# Accuracy           0.8386
# F1                 0.1361
# AUROC              0.6613
# Recall             0.2600
# Balanced Accuracy  0.5642
# Average Precision  0.0761

# %% [markdown]
# ### Undersampling

# %%
## Validación SVM + Undersampling
metricas_svm_under = evaluar_modelo(
    best_svm_under2,
    x_test_final,
    y_test_final,
    "SVM Undersampling"
)
# Out:
#                      Test
# Accuracy           0.7270
# F1                 0.1960
# AUROC              0.7989
# Recall             0.6800
# Balanced Accuracy  0.7047
# Average Precision  0.1611

# %% [markdown]
# ### Class - weight

# %%
## Validación SVM + Class Weight
metricas_svm_cw = evaluar_modelo(
    best_svm_cw2,
    x_test_final,
    y_test_final,
    "SVM Class Weight"
)
# Out:
#                      Test
# Accuracy           0.7290
# F1                 0.2108
# AUROC              0.8014
# Recall             0.7400
# Balanced Accuracy  0.7342
# Average Precision  0.1499

# %% [markdown]
# ### Undersampling + class_weight

# %%
## Validación SVM + Undersampling + Class Weight
metricas_svm_under_cw = evaluar_modelo(
    best_svm_under_cw2,
    x_test_final,
    y_test_final,
    "SVM Under + Class Weight"
)
# Out:
#                      Test
# Accuracy           0.7309
# F1                 0.2029
# AUROC              0.7996
# Recall             0.7000
# Balanced Accuracy  0.7163
# Average Precision  0.1588

# %% [markdown]
# ## Regresión logística

# %% [markdown]
# ### SMOTE

# %%
## Validación LR + SMOTE
metricas_lr_smote = evaluar_modelo(
    best_lr_smote2,
    x_test_final,
    y_test_final,
    "LR SMOTE"
)
# Out:
#                      Test
# Accuracy           0.7387
# F1                 0.2124
# AUROC              0.8014
# Recall             0.7200
# Balanced Accuracy  0.7299
# Average Precision  0.1562

# %% [markdown]
# ### Undersampling

# %%
## Validación LR + Undersampling
metricas_lr_under = evaluar_modelo(
    best_lr_under2,
    x_test_final,
    y_test_final,
    "LR Undersampling"
)
# Out:
#                      Test
# Accuracy           0.7339
# F1                 0.2093
# AUROC              0.8044
# Recall             0.7200
# Balanced Accuracy  0.7273
# Average Precision  0.1554

# %% [markdown]
# ### Class_weight

# %%
### Validación LR + Class Weight
metricas_lr_cw = evaluar_modelo(
    best_lr_cw2,
    x_test_final,
    y_test_final,
    "LR Class Weight"
)
# Out:
#                      Test
# Accuracy           0.7221
# F1                 0.2022
# AUROC              0.8087
# Recall             0.7200
# Balanced Accuracy  0.7211
# Average Precision  0.1488

# %% [markdown]
# ### Undersampling + class_weight

# %%
## Validación LR + Undersampling + Class Weight
metricas_lr_under_cw = evaluar_modelo(
    best_lr_under_cw2,
    x_test_final,
    y_test_final,
    "LR Under + Class Weight"
)
# Out:
#                      Test
# Accuracy           0.7339
# F1                 0.2093
# AUROC              0.8044
# Recall             0.7200
# Balanced Accuracy  0.7273
# Average Precision  0.1554

# %% [markdown]
# ## Redes neuronales

# %% [markdown]
# ### SMOTE

# %%
## Validación NN + SMOTE
metricas_nn_smote = evaluar_modelo(
    best_nn_smote2,
    x_test_df,
    y_test_nn,
    "NN SMOTE",
    es_nn=True
)
# Out:
#                      Test
# Accuracy           0.8513
# F1                 0.1364
# AUROC              0.6929
# Recall             0.2400
# Balanced Accuracy  0.5614
# Average Precision  0.0913

# %% [markdown]
# ### Undersampling

# %%
### Validación NN + Undersampling
metricas_nn_under = evaluar_modelo(
    best_nn_under2,
    x_test_df,
    y_test_nn,
    "NN Undersampling",
    es_nn=True
)
# Out:
#                      Test
# Accuracy           0.6888
# F1                 0.1804
# AUROC              0.7870
# Recall             0.7000
# Balanced Accuracy  0.6941
# Average Precision  0.1587

# %% [markdown]
# ### Class_weight

# %%
### Validación NN + Class Weight
metricas_nn_cw = evaluar_modelo(
    best_nn_cw2,
    x_test_df,
    y_test_nn,
    "NN Class Weight",
    es_nn=True
)
# Out:
#                      Test
# Accuracy           0.7436
# F1                 0.2156
# AUROC              0.8058
# Recall             0.7200
# Balanced Accuracy  0.7324
# Average Precision  0.1504

# %% [markdown]
# ### Undersampling + class_weight

# %%
### Validación NN + Undersampling + Class Weight

metricas_nn_under_cw = evaluar_modelo(
    best_nn_under_cw2,
    x_test_df,
    y_test_nn,
    "NN Under + Class Weight",
    es_nn=True
)
# Out:
#                      Test
# Accuracy           0.1673
# F1                 0.1052
# AUROC              0.7983
# Recall             1.0000
# Balanced Accuracy  0.5622
# Average Precision  0.1506

# %% [markdown]
# Se seleccionan los modelos entrenados con undersampling para la fase final de interpretabilidad, priorizando consistencia metodológica y estabilidad interpretativa

# %%
# ── Sklearn y XGBoost ────────────────────────────────────────
modelos_finales = {
    "rf_under":  best_rf_under2,
    "xgb_under": best_xgb_under2,
    "svm_under": best_svm_under2,
    "lr_under":  best_lr_under2,
}
with open(RUTA_BASE + "modelos_finales.pkl", "wb") as f:
    pickle.dump(modelos_finales, f)

# %%
# ── Red Neuronal ────────────────────────────────────────
model = best_nn_under2.model_
model.save(RUTA_BASE + "nn_under.keras")

# %% [markdown]
# # Gráfico entrenamiento

# %%
RUTA_BASE = "/content/drive/MyDrive/"
N_SPLITS, SEED = 5, 24   # nº folds de CV y semilla común

# Métricas usadas en la CV multimétrica
scoring = {
    "AUROC":   "roc_auc",
    "Recall":  make_scorer(recall_score, pos_label=1),
    "AvgPrec": "average_precision",
}

# Modelos sklearn/XGBoost guardados en pickle + red neuronal en formato Keras
with open(RUTA_BASE + "modelos_finales.pkl", "rb") as f:
    modelos = pickle.load(f)
modelos["nn_under"] = load_model(RUTA_BASE + "nn_under.keras")

# Particiones train (UNDER) y test. Convertimos las etiquetas "Sí"/"No" a 1/0
X_train = pd.read_csv(RUTA_BASE + "x_train_UNDER.csv")
y_train = (pd.read_csv(RUTA_BASE + "y_train_UNDER.csv").squeeze() == "Sí").astype(int)
X_test  = pd.read_csv(RUTA_BASE + "x_test_final.csv")
y_test  = (pd.read_csv(RUTA_BASE + "y_test_final.csv").squeeze() == "Sí").astype(int)

# Etiquetas legibles para los gráficos y tablas
LABELS = {"rf_under": "RF", "xgb_under": "XGB", "svm_under": "SVM",
          "lr_under": "LR", "nn_under": "NN"}

# Helper para obtener probabilidades de la clase positiva.
# Unifica el comportamiento de los modelos sklearn (predict_proba) y de la
# red neuronal Keras pura (predict + ravel)
def proba(modelo, X):
    if hasattr(modelo, "predict_proba"):
        return modelo.predict_proba(X)[:, 1]
    return modelo.predict(X.values if hasattr(X, "values") else X).ravel()

# %% [markdown]
# Validación cruzada multimétrica + boxplot

# %%
# La NN se reentrena dentro de la CV (no se puede clonar un modelo Keras
# ya ajustado), así que la reconstruimos con los hiperparámetros finales
def crear_nn():
    m = Sequential([
        Input(shape=(X_train.shape[1],)),
        Dense(16, activation="relu"),
        Dropout(0.5),
        Dense(1, activation="sigmoid"),
    ])
    m.compile(optimizer=Adam(0.005), loss="binary_crossentropy", metrics=["AUC"])
    return m

# CV estratificada compartida por todos los modelos
cv = StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=SEED)
records = []

# Cross-validate sobre cada modelo. Para la NN usamos un KerasClassifier
# nuevo (se entrena de cero en cada fold); para el resto, clone() basta.
for nombre, modelo in modelos.items():
    if nombre == "nn_under":
        estimator = KerasClassifier(model=crear_nn, epochs=100, batch_size=32,
                                    verbose=0, random_state=SEED)
        scores = cross_validate(estimator, X_train, y_train, cv=cv, scoring=scoring)
    else:
        scores = cross_validate(clone(modelo), X_train, y_train, cv=cv,
                                scoring=scoring, n_jobs=-1)
    # Aplanamos los scores a formato largo (un score por fila) para seaborn
    for met in scoring:
        for s in scores[f"test_{met}"]:
            records.append({"Modelo": LABELS[nombre], "Métrica": met, "Score": s})

# Convertimos a DataFrame y fijamos orden categórico para el gráfico
df_cv = pd.DataFrame(records)
for col, cats in {"Modelo":  ["RF", "XGB", "SVM", "LR", "NN"],
                  "Métrica": ["AUROC", "Recall", "AvgPrec"]}.items():
    df_cv[col] = pd.Categorical(df_cv[col], categories=cats, ordered=True)

# Boxplot con las tres métricas agrupadas por modelo
palette = {"AUROC": "#378ADD", "Recall": "#F0AD4E", "AvgPrec": "#0F6E56"}
fig, ax = plt.subplots(figsize=(11, 5))
sns.boxplot(data=df_cv, x="Modelo", y="Score", hue="Métrica",
            palette=palette, width=0.7, whis=(0, 100), showfliers=False, ax=ax)
ax.set(xlabel="Modelo", ylabel="Valor de la métrica (CV 5-fold)",
       title="Rendimiento por modelo y métrica — Kaggle", ylim=(0.70, 0.90))
ax.legend(title="Métrica", frameon=False,
          bbox_to_anchor=(1.02, 0.5), loc="center left")  # leyenda fuera del plot
ax.grid(axis="y", alpha=0.3, linestyle="--")
ax.set_axisbelow(True)
for s in ["top", "right"]:
    ax.spines[s].set_visible(False)
plt.tight_layout()
plt.savefig(RUTA_BASE + "cv_boxplot_kaggle.png", dpi=150, bbox_inches="tight")
plt.show()

# Tabla resumen (media y desviación típica por modelo y métrica)
resumen = (df_cv.groupby(["Modelo", "Métrica"], observed=True)["Score"]
                .agg(["mean", "std"]).round(4))
df_cv.to_csv(RUTA_BASE + "cv_scores_kaggle.csv", index=False)
print(resumen)
# Out:
# WARNING:tensorflow:5 out of the last 13 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7eab2c39de40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 13 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7eab2c0b9120> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#                   mean     std
# Modelo Métrica
# RF     AUROC    0.8433  0.0616
#        Recall   0.8290  0.0604
#        AvgPrec  0.8110  0.0727
# XGB    AUROC    0.8440  0.0521
#        Recall   0.8440  0.0553
#        AvgPrec  0.8168  0.0655
# SVM    AUROC    0.8319  0.0549
#        Recall   0.7990  0.0468
#        AvgPrec  0.8058  0.0617
# LR     AUROC    0.8405  0.0559
#        Recall   0.8141  0.0574
#        AvgPrec  0.8183  0.0527
# NN     AUROC    0.8033  0.0530
#        Recall   0.7987  0.0600
#        AvgPrec  0.7859  0.0733

# %% [markdown]
# Predicciones sobre test y tabla de métricas

# %%
# Calculamos probabilidades y predicciones binarias (umbral 0.5) una sola vez
probs = {LABELS[n]: proba(m, X_test) for n, m in modelos.items()}
preds = {k: (p >= 0.5).astype(int) for k, p in probs.items()}

# Tabla de las tres métricas para cada modelo
metricas_test = pd.DataFrame({
    k: [roc_auc_score(y_test, probs[k]),
        average_precision_score(y_test, probs[k]),
        recall_score(y_test, preds[k], pos_label=1)]
    for k in probs
}, index=["AUROC", "Average Precision", "Recall"])
print(metricas_test.round(4))
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#                        RF     XGB     SVM      LR      NN
# AUROC              0.8037  0.8091  0.7989  0.8044  0.7927
# Average Precision  0.1532  0.1607  0.1611  0.1554  0.1572
# Recall             0.7200  0.7000  0.6800  0.7200  0.6400

# %% [markdown]
# Figura ROC y matriz de confusión para los cinco modelos

# %%
orden = ["RF", "XGB", "SVM", "LR", "NN"]

# Layout compartido: 3 paneles arriba (cols 0-1, 2-3, 4-5) y 2 centrados abajo (1-2, 3-4)
def crear_axes_5paneles(fig):
    gs = GridSpec(2, 6, figure=fig, hspace=0.45, wspace=0.40)
    return [fig.add_subplot(gs[0, i:i+2]) for i in (0, 2, 4)] + \
           [fig.add_subplot(gs[1, i:i+2]) for i in (1, 3)]

# --- Figura ROC (solo el nombre del modelo en el título) ---
fig = plt.figure(figsize=(16, 9))
for axis, nombre in zip(crear_axes_5paneles(fig), orden):
    fpr, tpr, _ = roc_curve(y_test, probs[nombre], pos_label=1)
    axis.plot(fpr, tpr, color="steelblue", lw=2, label=f"AUROC = {auc(fpr, tpr):.4f}")
    axis.plot([0, 1], [0, 1], color="gray", linestyle="--", lw=1)
    axis.set(xlabel="Tasa de falsos positivos", ylabel="Tasa de verdaderos positivos",
             title=nombre, xlim=(0, 1), ylim=(-0.02, 1.06))
    axis.legend(loc="lower right", fontsize=9)
    axis.grid(True, alpha=0.3)
fig.suptitle("Curvas ROC por modelo — Kaggle (undersampling)", fontsize=13, y=0.98)
fig.tight_layout(rect=[0, 0, 1, 0.96])
plt.savefig(RUTA_BASE + "figura_4_3a_roc_kaggle.png", dpi=300, bbox_inches="tight")
plt.show()

# --- Figura matrices de confusión (mismo layout) ---
fig = plt.figure(figsize=(16, 9))
for axis, nombre in zip(crear_axes_5paneles(fig), orden):
    y_pred = (probs[nombre] >= 0.5).astype(int)
    cm = confusion_matrix(y_test, y_pred, labels=[0, 1])
    cm_norm = cm / cm.sum(axis=1, keepdims=True)  # normalizada por clase real (recall por fila)
    etiquetas = np.array([[f"{c}\n({p:.2f})" for c, p in zip(fc, fp)]
                          for fc, fp in zip(cm, cm_norm)])
    sns.heatmap(cm_norm, annot=etiquetas, fmt="", cmap="Blues", cbar=False,
                vmin=0, vmax=1, square=True, ax=axis, annot_kws={"fontsize": 9},
                xticklabels=["No ictus", "Ictus"], yticklabels=["No ictus", "Ictus"])
    axis.set(xlabel="Predicción", ylabel="Valor real", title=nombre)
fig.suptitle("Matrices de confusión por modelo — Kaggle (undersampling, umbral = 0,5)",
             fontsize=13, y=0.98)
fig.tight_layout(rect=[0, 0, 1, 0.96])
plt.savefig(RUTA_BASE + "figura_4_3b_confusion_kaggle.png", dpi=300, bbox_inches="tight")
plt.show()
# Out:
# /tmp/ipykernel_472/4254183675.py:20: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout(rect=[0, 0, 1, 0.96])
# /tmp/ipykernel_472/4254183675.py:38: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout(rect=[0, 0, 1, 0.96])
